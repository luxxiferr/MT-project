# %% [markdown]
# # English-to-Spanish translation with a sequence-to-sequence Transformer
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2021/05/26<br>
# **Last modified:** 2022/02/25<br>
# **Description:** Implementing a sequence-to-sequene Transformer and training it on a machine translation task.

# %% [markdown]
# ## Introduction
#
# In this example, we'll build a sequence-to-sequence Transformer model, which
# we'll train on an English-to-Spanish machine translation task.
#
# You'll learn how to:
#
# - Vectorize text using the Keras `TextVectorization` layer.
# - Implement a `TransformerEncoder` layer, a `TransformerDecoder` layer,
# and a `PositionalEmbedding` layer.
# - Prepare data for training a sequence-to-sequence model.
# - Use the trained model to generate translations of never-seen-before
# input sentences (sequence-to-sequence inference).
#
# The code featured here is adapted from the book
# [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition)
# (chapter 11: Deep learning for text).
# The present example is fairly barebones, so for detailed explanations of
# how each building block works, as well as the theory behind Transformers,
# I recommend reading the book.

# %% [markdown]
# We will try to find the best paramethers adjusting them to different input lenghts:
#
#
# a) 1-3 words
#
#
# b) 4-10 words
#
#
# c) >10 words

# %% [markdown]
# ## Setup

# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %% [markdown]
# ## Downloading the data
#
# We'll be working with an English-to-Spanish translation dataset
# provided by [Anki](https://www.manythings.org/anki/). But we will split it in three different files according to the input text leghts. Let's load it from Google Drive:

# %%
text_file = keras.utils.get_file(
    fname="spa-eng.zip",
    origin="http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip",
    extract=True,
)
text_file = pathlib.Path(text_file).parent / "spa-eng" / "spa.txt"

# %% [markdown]
# ## Parsing the data
#
# Each line contains an English sentence and its corresponding Spanish sentence.
# The English sentence is the *source sequence* and Spanish one is the *target sequence*.
# We prepend the token `"[start]"` and we append the token `"[end]"` to the Spanish sentence.
#
# *Run only one of the three chunks of code at a time*

# %%
#Takes into account only sentences in English of less than 4 words
with open(text_file) as f:
     lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
  eng, spa = line.split("\t")
  spa = "[start] " + spa + " [end]"
  if len(eng.split())< 4: 
    text_pairs.append((eng, spa))

# %%
#Takes into account only sentences in English of 4 to 10 words
#with open(text_file) as f:
#   lines = f.read().split("\n")[:-1]
#text_pairs = []
#for line in lines:
#    eng, spa = line.split("\t")
#    spa = "[start] " + spa + " [end]"
#    if 4 <= len(eng.split()) <11: #
#      text_pairs.append((eng, spa))

# %%
#Takes into account only sentences in English of more than 10 words
# with open(text_file) as f:
#     lines = f.read().split("\n")[:-1]
# text_pairs = []
# for line in lines:
#     eng, spa = line.split("\t")
#     spa = "[start] " + spa + " [end]"
#     if len(eng.split()) > 11: #
#       text_pairs.append((eng, spa))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(10):
    print(random.choice(text_pairs))
# Out:
# ("Someone's watching me.", '[start] Alguien me está vigilando. [end]')
# ('Keep this.', '[start] Guarde esto. [end]')
# ('Tom likes Mary.', '[start] A Tom le gusta Mary. [end]')
# ('She likes tigers.', '[start] A ella le gustan los tigres. [end]')
# ('Do not interfere!', '[start] ¡No interfieras! [end]')
# ('That will do.', '[start] Con eso bastará. [end]')
# ("I didn't ask.", '[start] Yo no pregunté. [end]')
# ('Have him come.', '[start] Hazlo venir. [end]')
# ('I loved that.', '[start] Eso me gustó. [end]')
# ('Come on.', '[start] Ándale. [end]')

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set,
# and a test set.

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 12456 total pairs
# 8720 training pairs
# 1868 validation pairs
# 1868 test pairs

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use two instances of the `TextVectorization` layer to vectorize the text
# data (one for English and one for Spanish),
# that is to say, to turn the original strings into integer sequences
# where each integer represents the index of a word in a vocabulary.
#
# The English layer will use the default string standardization (strip punctuation characters)
# and splitting scheme (split on whitespace), while
# the Spanish layer will use a custom standardization, where we add the character
# `"¿"` to the set of punctuation characters to be stripped.
#
# Note: in a production-grade machine translation model, I would not recommend
# stripping the punctuation characters in either language. Instead, I would recommend turning
# each punctuation character into its own token,
# which you could achieve by providing a custom `split` function to the `TextVectorization` layer.

# %%
strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 64


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size, output_mode="int", output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %% [markdown]
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond)
# using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple `(inputs, targets)`, where:
#
# - `inputs` is a dictionary with the keys `encoder_inputs` and `decoder_inputs`.
# `encoder_inputs` is the vectorized source sentence and `encoder_inputs` is the target sentence "so far",
# that is to say, the words 0 to N used to predict word N+1 (and beyond) in the target sentence.
# - `target` is the target sentence offset by one step:
# it provides the next words in the target sentence -- what the model will try to predict.

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return ({"encoder_inputs": eng, "decoder_inputs": spa[:, :-1],}, spa[:, 1:])


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# *Let*'s take a quick look at the sequence shapes
# (we have batches of 64 pairs, and all sequences are 20 steps long):

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"].shape: (64, 20)
# targets.shape: (64, 20)

# %% [markdown]
# ## Building the model
#
# Our sequence-to-sequence Transformer consists of a `TransformerEncoder`
# and a `TransformerDecoder` chained together. To make the model aware of word order,
# we also use a `PositionalEmbedding` layer.
#
# The source sequence will be pass to the `TransformerEncoder`,
# which will produce a new representation of it.
# This new representation will then be passed
# to the `TransformerDecoder`, together with the target sequence so far (target words 0 to N).
# The `TransformerDecoder` will then seek to predict the next words in the target sequence (N+1 and beyond).
#
# A key detail that makes this possible is causal masking
# (see method `get_causal_attention_mask()` on the `TransformerDecoder`).
# The `TransformerDecoder` sees the entire sequences at once, and thus we must make
# sure that it only uses information from target tokens 0 to N when predicting token N+1
# (otherwise, it could use information from the future, which would
# result in a model that cannot be used at inference time).

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads,
        })
        return config


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)
    def get_config(self):
        config = super().get_config()
        config.update({
            "sequence_length": self.sequence_length,
            "vocab_size": self.vocab_size,
            "embed_dim": self.embed_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "latent_dim": self.latent_dim,
            "num_heads": self.num_heads,
        })
        return config

# %% [markdown]
# Next, we assemble the end-to-end model.

# %%
embed_dim = 512
latent_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %% [markdown]
# ## Training our model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data.
# Note that machine translation typically uses BLEU scores as well as other metrics, rather than accuracy.
#
# Here we only train for 1 epoch, but to get the model to actually converge
# you should train for at least 30 epochs.

# %%
epochs = 30  # This should be at least 30 for convergence

transformer.summary()
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding_2 (Positi  (None, None, 512)   7690240     ['encoder_inputs[0][0]']
#  onalEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder_1 (Transfo  (None, None, 512)   10503168    ['positional_embedding_2[0][0]']
#  rmerEncoder)
#
#  model_3 (Functional)           (None, None, 15000)  34290840    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder_1[0][0]']
#
# ==================================================================================================
# Total params: 52,484,248
# Trainable params: 52,484,248
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 137/137 [==============================] - 31s 171ms/step - loss: 4.3980 - accuracy: 0.4476 - val_loss: 3.6239 - val_accuracy: 0.5221
# Epoch 2/30
# 137/137 [==============================] - 18s 128ms/step - loss: 3.4605 - accuracy: 0.5321 - val_loss: 3.2614 - val_accuracy: 0.5489
# Epoch 3/30
# 137/137 [==============================] - 17s 127ms/step - loss: 2.8658 - accuracy: 0.5858 - val_loss: 2.9709 - val_accuracy: 0.5787
# Epoch 4/30
# 137/137 [==============================] - 17s 126ms/step - loss: 2.5025 - accuracy: 0.6200 - val_loss: 2.8590 - val_accuracy: 0.5911
# Epoch 5/30
# 137/137 [==============================] - 18s 134ms/step - loss: 2.1635 - accuracy: 0.6584 - val_loss: 2.7481 - val_accuracy: 0.6105
# Epoch 6/30
# 137/137 [==============================] - 17s 127ms/step - loss: 1.8837 - accuracy: 0.6900 - val_loss: 2.6773 - val_accuracy: 0.6221
# Epoch 7/30
# 137/137 [==============================] - 17s 128ms/step - loss: 1.9558 - accuracy: 0.6809 - val_loss: 2.6513 - val_accuracy: 0.6250
# Epoch 8/30
# 137/137 [==============================] - 17s 127ms/step - loss: 1.5283 - accuracy: 0.7302 - val_loss: 2.5303 - val_accuracy: 0.6455
# Epoch 9/30
# 137/137 [==============================] - 17s 126ms/step - loss: 1.3750 - accuracy: 0.7513 - val_loss: 2.4991 - val_accuracy: 0.6452
# Epoch 10/30
# 137/137 [==============================] - 17s 127ms/step - loss: 1.2048 - accuracy: 0.7732 - val_loss: 2.4931 - val_accuracy: 0.6512
# Epoch 11/30
# 137/137 [==============================] - 17s 126ms/step - loss: 1.0957 - accuracy: 0.7906 - val_loss: 2.5326 - val_accuracy: 0.6554
# Epoch 12/30
# 137/137 [==============================] - 17s 127ms/step - loss: 1.0052 - accuracy: 0.8040 - val_loss: 2.4393 - val_accuracy: 0.6623
# Epoch 13/30
# 137/137 [==============================] - 17s 127ms/step - loss: 0.8954 - accuracy: 0.8241 - val_loss: 2.4916 - val_accuracy: 0.6606
# Epoch 14/30
# 137/137 [==============================] - 17s 127ms/step - loss: 0.8673 - accuracy: 0.8330 - val_loss: 2.4595 - val_accuracy: 0.6677
# Epoch 15/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.7814 - accuracy: 0.8470 - val_loss: 2.5225 - val_accuracy: 0.6642
# Epoch 16/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.7080 - accuracy: 0.8592 - val_loss: 2.5532 - val_accuracy: 0.6599
# Epoch 17/30
# 137/137 [==============================] - 17s 127ms/step - loss: 0.6802 - accuracy: 0.8655 - val_loss: 2.5507 - val_accuracy: 0.6699
# Epoch 18/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.6205 - accuracy: 0.8750 - val_loss: 2.5737 - val_accuracy: 0.6680
# Epoch 19/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.5818 - accuracy: 0.8829 - val_loss: 2.6184 - val_accuracy: 0.6618
# Epoch 20/30
# 137/137 [==============================] - 18s 133ms/step - loss: 0.5551 - accuracy: 0.8879 - val_loss: 2.6049 - val_accuracy: 0.6684
# Epoch 21/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.5151 - accuracy: 0.8926 - val_loss: 2.6317 - val_accuracy: 0.6590
# Epoch 22/30
# 137/137 [==============================] - 17s 127ms/step - loss: 0.5040 - accuracy: 0.8961 - val_loss: 2.6701 - val_accuracy: 0.6690
# Epoch 23/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.4699 - accuracy: 0.9010 - val_loss: 2.7313 - val_accuracy: 0.6624
# Epoch 24/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.4528 - accuracy: 0.9076 - val_loss: 2.7330 - val_accuracy: 0.6623
# Epoch 25/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.4297 - accuracy: 0.9112 - val_loss: 2.7028 - val_accuracy: 0.6634
# Epoch 26/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.4432 - accuracy: 0.9083 - val_loss: 2.6531 - val_accuracy: 0.6710
# Epoch 27/30
# 137/137 [==============================] - 17s 125ms/step - loss: 0.4294 - accuracy: 0.9107 - val_loss: 2.7232 - val_accuracy: 0.6708
# Epoch 28/30
# 137/137 [==============================] - 17s 127ms/step - loss: 0.4011 - accuracy: 0.9152 - val_loss: 2.7648 - val_accuracy: 0.6592
# Epoch 29/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.3923 - accuracy: 0.9170 - val_loss: 2.7600 - val_accuracy: 0.6660
# Epoch 30/30
# 137/137 [==============================] - 17s 126ms/step - loss: 0.3713 - accuracy: 0.9219 - val_loss: 2.7884 - val_accuracy: 0.6650

# %% [markdown]
# ## Decoding test sentences
#
# Finally, let's demonstrate how to translate brand new English sentences.
# We simply feed into the model the vectorized English sentence
# as well as the target token `"[start]"`, then we repeatedly generated the next token, until
# we hit the token `"[end]"`.

# %%
spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)
    print(_, input_sentence, translated)
# Out:
# 0 You're nuts! [start] estás loco [end]
# 1 I'm grieving. [start] soy imparcial [end]
# 2 I feel tired. [start] yo siento cansada [end]
# 3 Bite your tongue. [start] Átate los cordones [end]
# 4 Make a list. [start] haz una lista [end]
# 5 Flip a coin. [start] los una zorra [end]
# 6 Wait here. [start] esperad aquí [end]
# 7 You aren't stupid. [start] no sos estúpido [end]
# 8 I'm so alone. [start] estoy tan solo [end]
# 9 Do fish sleep? [start] lo dormir [end]
# 10 Summer is coming. [start] el invierno se acerca [end]
# 11 I love golf. [start] me encantan las bodas [end]
# 12 Keep in touch. [start] mantente en contacto [end]
# 13 I've been suspended. [start] he estado preocupada [end]
# 14 Keep still. [start] mantente quieto [end]
# 15 Come over. [start] veníos [end]
# 16 It is second-hand. [start] es maravilloso [end]
# 17 I'll change. [start] voy a cambiar [end]
# 18 Somebody poisoned Tom. [start] alguien a tom [end]
# 19 That's obvious. [start] es obvio [end]
# 20 You want this? [start] eres este [end]
# 21 Be confident. [start] sé confiado [end]
# 22 He denied everything. [start] Él lo negó todo [end]
# 23 Tom likes games. [start] a tom le gusta la juegos [end]
# 24 Say cheese. [start] di patata [end]
# 25 We searched everywhere. [start] estábamos en todas partes [end]
# 26 Tom shed tears. [start] tom parece exhausto [end]
# 27 She cried bitterly. [start] ella lloró [end]
# 28 Tom continued eating. [start] tom siguió comiendo [end]
# 29 I must refuse. [start] yo debo esconderme [end]

# %% [markdown]
# # Evaluation
#
# *   Implement BLEU

# %% [markdown]
# ## BLEU

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %%
import random
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %%
def calculate_bleu(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    smoothie = SmoothingFunction().method4  # smoothing to handle cases with 0 counts
    return sentence_bleu([reference_tokens], candidate_tokens, smoothing_function=smoothie)


test_eng_texts = []
for pair in test_pairs:
    eng_sentence = pair[0]
    test_eng_texts.append(eng_sentence)

test_spa_texts = []
for pair in test_pairs:
    spa_sentence = pair[1]
    test_spa_texts.append(spa_sentence)

print(len(test_eng_texts))

bleu_scores = []
for idx in range(len(test_eng_texts)):
    input_sentence = test_eng_texts[idx]
    target_translation = test_spa_texts[idx]
    translated = decode_sequence(input_sentence)
    translated = translated.replace("[start]", "").replace("[end]", "").strip()

    bleu_score = calculate_bleu(target_translation, translated)
    bleu_scores.append(bleu_score)

    print(idx, input_sentence, translated, "| BLEU score:", bleu_score)

average_bleu = np.mean(bleu_scores)
print("\n\nAverage BLEU score:", average_bleu)
# Out:
# 1868
# 0 We're having dinner. estamos colgados en la cena | BLEU score: 0
# 1 Why not? por qué no interfieras | BLEU score: 0.04753271977233425
# 2 Send him in. mándalo dentro | BLEU score: 0
# 3 I ate it. lo conozco | BLEU score: 0.015071184180845467
# 4 I like climbing. me gusta la luz de las velas | BLEU score: 0.081939171811711
# 5 This doesn't fit. esto no cabe | BLEU score: 0.03722145753922423
# 6 Nobody's indispensable. nadie sabrá | BLEU score: 0
# 7 I don't eat. yo no como comer | BLEU score: 0
# 8 Ask me tomorrow. pregunta en mañana | BLEU score: 0
# 9 Raise your hands! levantá tus manos | BLEU score: 0
# 10 Here's your bag. aquí está tu cartera | BLEU score: 0.10202995073993343
# 11 I see them. las veo | BLEU score: 0
# 12 We're Canadians. somos abogados | BLEU score: 0
# 13 They waited. se abrazaron | BLEU score: 0
# 14 Kiss Tom. besen a tomás | BLEU score: 0.03722145753922423
# 15 Was I snoring? estaba equivocada | BLEU score: 0
# 16 You're too idealistic. eres demasiado generoso | BLEU score: 0.03722145753922423
# 17 What's Tom hiding? qué está ocultando | BLEU score: 0.07790941292260128
# 18 What'll we do? somos tengo | BLEU score: 0
# 19 Turn it off. apágalo | BLEU score: 0
# 20 Think about that. piénsatelo | BLEU score: 0
# 21 I played tennis. jugaba al tenis | BLEU score: 0.07790941292260128
# 22 Speak more slowly. habla más despacio | BLEU score: 0.03722145753922423
# 23 That's our secret. esa es nuestro secreto | BLEU score: 0.10202995073993343
# 24 Try this candy. prueba esto | BLEU score: 0
# 25 I'm so happy. soy tan feliz | BLEU score: 0.03722145753922423
# 26 You're unfair. eres injusto | BLEU score: 0
# 27 You were nice. fuisteis arrogantes | BLEU score: 0
# 28 Nobody is speaking. nadie está hablando | BLEU score: 0.07790941292260128
# 29 It's a dictionary. es un turista | BLEU score: 0.03722145753922423
# 30 Who invented karaoke? quién va a el karaoke | BLEU score: 0.037374807627842434
# 31 Is it yours? es suyo | BLEU score: 0
# 32 It's 8:30. es usted | BLEU score: 0
# 33 Somebody poisoned Tom. alguien a tom | BLEU score: 0.026670339752046985
# 34 Be confident. sé confiado | BLEU score: 0
# 35 Tom's unstoppable. tom está viniendo | BLEU score: 0
# 36 Does truth matter? la verdad importa | BLEU score: 0.03722145753922423
# 37 Things eventually changed. las cosas cambiaron en las cosas en las cosas en las cosas cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron | BLEU score: 0.013038525962482981
# 38 They're enjoying themselves. ellas se divierten | BLEU score: 0
# 39 Tom wanted revenge. tom quería con venganza | BLEU score: 0.03701851938020757
# 40 He resigned. Él renunció | BLEU score: 0.02484818193359921
# 41 I'm in Perth. estoy en línea | BLEU score: 0.03722145753922423
# 42 Have another cup. sírvase otra copa | BLEU score: 0.03722145753922423
# 43 You look awful. pareces aburrido | BLEU score: 0
# 44 It was exhilarating. fue emocionante | BLEU score: 0
# 45 That's Tom's apartment. esa es el apartamento de tom | BLEU score: 0.36409302398068727
# 46 Who invented that? quién piensa eso | BLEU score: 0
# 47 I got divorced. me pidieron divorciada | BLEU score: 0
# 48 We're not family. no somos familia | BLEU score: 0.03722145753922423
# 49 I'm not Tom. no soy tom | BLEU score: 0.03722145753922423
# 50 Flip a coin. los una zorra | BLEU score: 0.03722145753922423
# 51 I'd be honored. yo sé clemente | BLEU score: 0
# 52 They're not soldiers. no son criminales | BLEU score: 0.03722145753922423
# 53 I like milk. me gusta la leche | BLEU score: 0.10202995073993343
# 54 Tom embraced Mary. tom abandonó a mary | BLEU score: 0.03701851938020757
# 55 It's nearly 2:30. van a ser las dos y media | BLEU score: 0.16738117723186785
# 56 Go meet Tom. ve a tom | BLEU score: 0.01911013349598245
# 57 You're sick! estáis mal | BLEU score: 0
# 58 I'm behind you soy tu usted | BLEU score: 0
# 59 You survived. sobreviviste | BLEU score: 0
# 60 I've heard rumors. oí por favor | BLEU score: 0
# 61 I'm impressed. estoy impresionada | BLEU score: 0
# 62 I'm confused now. ahora confundida | BLEU score: 0
# 63 Don't disturb me. no me molestes | BLEU score: 0.03722145753922423
# 64 It hurts. duele | BLEU score: 0
# 65 Stop harassing Tom. deja de tom | BLEU score: 0.01911013349598245
# 66 That's correct. eso es cierto | BLEU score: 0
# 67 I missed you. te extrañé | BLEU score: 0
# 68 Breathe normally. inspira profundamente | BLEU score: 0
# 69 Women are beautiful. las mujeres son guapa | BLEU score: 0.10202995073993343
# 70 Can I begin? puedo ir | BLEU score: 0
# 71 Something must've happened. algo odia algo | BLEU score: 0
# 72 I agreed. yo accedí | BLEU score: 0
# 73 Should I go? deberíamos seguir | BLEU score: 0
# 74 They've been arrested. le han tendido una emboscada | BLEU score: 0
# 75 He became famous. Él se puso como | BLEU score: 0.10202995073993343
# 76 Flip a coin. los una zorra | BLEU score: 0.01911013349598245
# 77 He teaches English. Él habla inglés | BLEU score: 0.01911013349598245
# 78 Go get it. ve a por ello | BLEU score: 0.10202995073993343
# 79 I didn't sing. yo no canto | BLEU score: 0.03722145753922423
# 80 Who's that man? quién es aquel hombre | BLEU score: 0.03701851938020757
# 81 He is intelligent. Él es inteligente | BLEU score: 0.10873134470594509
# 82 Try again. prueba otra vez | BLEU score: 0.03722145753922423
# 83 He went shopping. Él salió a compras | BLEU score: 0.028830051881449627
# 84 I am exhausted. estoy reventado | BLEU score: 0
# 85 You know everything. usted sabe todo | BLEU score: 0
# 86 Just take one. cojan solo una | BLEU score: 0.03722145753922423
# 87 I speak fast. yo hablo rápido | BLEU score: 0
# 88 They're already here. ellas ya están aquí | BLEU score: 0.04753271977233425
# 89 I'm not sad. no estoy triste | BLEU score: 0.03722145753922423
# 90 Tie your shoelaces. Átate los cordones | BLEU score: 0.03722145753922423
# 91 You shouldn't go. por preguntarme ahí | BLEU score: 0
# 92 It's dirty work. es trabajo trabajar | BLEU score: 0.03722145753922423
# 93 Loosen it. suéltala | BLEU score: 0
# 94 Tom's adopted. tom es soy | BLEU score: 0.03722145753922423
# 95 I'm so stupid. es muy tonto | BLEU score: 0
# 96 I hate riddles. odio el odio a los odio | BLEU score: 0.03759340464156993
# 97 People like me. caigo bien a la gente | BLEU score: 0.09923912030377631
# 98 Cook for me. cocina para mí | BLEU score: 0
# 99 Come aboard. sal a bordo | BLEU score: 0.03722145753922423
# 100 You're turning red. tú te estás poniendo rojo | BLEU score: 0.037374807627842434
# 101 They all knew. lo supieron | BLEU score: 0.015071184180845467
# 102 Let's finish this. comamos | BLEU score: 0
# 103 Everything went black. todo anduvo | BLEU score: 0
# 104 He ran. Él corrió | BLEU score: 0.02484818193359921
# 105 I despise you. yo te menosprecio | BLEU score: 0.03722145753922423
# 106 Be realistic! sé exhaustivo | BLEU score: 0
# 107 Tom looks tense. tom parece estar impaciente | BLEU score: 0.04753271977233425
# 108 Nobody likes Tom. nadie le gusta a tom | BLEU score: 0.037374807627842434
# 109 That's serious. eso es en serio | BLEU score: 0.04753271977233425
# 110 I'm hit! soy la fecha | BLEU score: 0
# 111 God bless you! dios eres la usted | BLEU score: 0
# 112 Help! ¡ayuda | BLEU score: 0
# 113 We're friends. somos amigas | BLEU score: 0
# 114 Where's the bread? dónde está el en dónde está el dónde está el en dónde está el dónde está las dónde está dónde | BLEU score: 0.029639798258145823
# 115 I'll walk. voy a andar | BLEU score: 0
# 116 Check again. compruébalo otra vez | BLEU score: 0
# 117 There's no hurry. hace falta favor | BLEU score: 0
# 118 I'm from Kyoto. soy de los estados unidos | BLEU score: 0.0456496931223525
# 119 Tom betrayed me. tom me traicionó | BLEU score: 0.03722145753922423
# 120 He denied everything. Él lo negó todo | BLEU score: 0
# 121 I couldn't sleep. no pude dormir | BLEU score: 0.03722145753922423
# 122 They're good. están bien | BLEU score: 0
# 123 Who wants it? quién lo quiere | BLEU score: 0.03722145753922423
# 124 She is French. es guapa | BLEU score: 0.015071184180845467
# 125 Are you Japanese? usted es japonés | BLEU score: 0
# 126 You're unfair. eres injusto | BLEU score: 0
# 127 Keep on smiling. continuad sonriendo de sonriendo | BLEU score: 0
# 128 It's already late. ya se nos hizo tarde | BLEU score: 0
# 129 I gave up. yo adoro el teléfono | BLEU score: 0
# 130 You're very skeptical. eres muy escéptica | BLEU score: 0.03722145753922423
# 131 What's today's menu? qué menú es en serio | BLEU score: 0.029793304282441858
# 132 Tom wasn't kidding. tom no estaba jodiendo | BLEU score: 0.10202995073993343
# 133 Make an offer. he estado guapa | BLEU score: 0
# 134 That's me. eso yo | BLEU score: 0
# 135 Tom started whining. tom empezó a comer | BLEU score: 0.03701851938020757
# 136 Keep the secret. seguí secreto | BLEU score: 0
# 137 You're babbling. tú estás murmurando | BLEU score: 0.03722145753922423
# 138 You're ignoring me. estás me odia | BLEU score: 0.03722145753922423
# 139 Take it. hagámoslo | BLEU score: 0
# 140 They're not coming. no son idiotas | BLEU score: 0.026670339752046985
# 141 It's a secret. es secreto | BLEU score: 0
# 142 Are you bald? estás tú calvo | BLEU score: 0
# 143 Tom bowed. tom se inclinó | BLEU score: 0.03722145753922423
# 144 Tom continued writing. tom siguió escribiendo | BLEU score: 0
# 145 Let's celebrate. ¡Órale | BLEU score: 0
# 146 Let's chat. vamos a charlar | BLEU score: 0
# 147 He gave up. Él se rindieron | BLEU score: 0
# 148 What gives? qué pasa | BLEU score: 0
# 149 Tom came yesterday. tom se ayer | BLEU score: 0
# 150 I'm staying here. soy aquí | BLEU score: 0
# 151 I like puzzles. me gusta la luz de las velas | BLEU score: 0
# 152 Are they cops? están satisfechos | BLEU score: 0
# 153 Hurry up, Tom. ¡apúrensen muchachas | BLEU score: 0
# 154 Mary looks beautiful. mary se ve hermosa | BLEU score: 0
# 155 You're home early. estás en la temprano | BLEU score: 0
# 156 Is it good? es tú | BLEU score: 0
# 157 I'll be alone. voy a estar solo | BLEU score: 0
# 158 How was Boston? ¡qué fue boston | BLEU score: 0
# 159 Tom refused. tom en banda en banda | BLEU score: 0
# 160 My name's Tom. me llamo tom | BLEU score: 0
# 161 See above. véase arriba | BLEU score: 0
# 162 I'll remember that. le recuerda eso | BLEU score: 0
# 163 She admired him. ella lo perdonó | BLEU score: 0.03722145753922423
# 164 Read after me. lean después de mí | BLEU score: 0.10202995073993343
# 165 You're too modest. sos demasiado generoso | BLEU score: 0.03722145753922423
# 166 Stay right there. mantente en allí | BLEU score: 0
# 167 You want this? eres este | BLEU score: 0
# 168 I didn't stop. yo no yo | BLEU score: 0.026670339752046985
# 169 They all know. todos los conocen | BLEU score: 0
# 170 They already know. ya son sensatos | BLEU score: 0.03722145753922423
# 171 Watch us. déjanos | BLEU score: 0
# 172 I watched you. yo observé | BLEU score: 0
# 173 Tom likes games. a tom le gusta la juegos | BLEU score: 0.026936851496754878
# 174 Stop it. déjalo | BLEU score: 0
# 175 Need anything else? cualquier cosa se cualquier cosa | BLEU score: 0
# 176 You must try. tienes que irte | BLEU score: 0.03722145753922423
# 177 You're very clever. eres muy listo | BLEU score: 0.03722145753922423
# 178 Tom escaped injury. tom evitó males mayores | BLEU score: 0
# 179 I'll change. voy a cambiar | BLEU score: 0
# 180 He's really quick. Él es realmente rápido | BLEU score: 0.10202995073993343
# 181 Tom isn't dumb. tom no es estúpido | BLEU score: 0.10202995073993343
# 182 Tom was adopted. tom fue despedido | BLEU score: 0.03722145753922423
# 183 Think about it. piénsatelo | BLEU score: 0
# 184 That's the attitude. esa es la emergencia | BLEU score: 0.10202995073993343
# 185 I ate caviar. yo comió quedito | BLEU score: 0
# 186 Stand by. un momento | BLEU score: 0
# 187 I was disillusioned. yo estaba desilusionado | BLEU score: 0
# 188 Just say yes. di que sí | BLEU score: 0.07790941292260128
# 189 I'm fixing something. soy algo | BLEU score: 0
# 190 Unfasten the pin. ¡qué los estados unidos | BLEU score: 0
# 191 Close the gate. cierra las persianas | BLEU score: 0
# 192 Tom is energetic. tom está implicado | BLEU score: 0
# 193 I got hit. me pidieron identificarme | BLEU score: 0
# 194 They're identical. están rotos | BLEU score: 0
# 195 Tom was scared. tom fue asustado | BLEU score: 0
# 196 That's obscene. ¡eso es obsceno | BLEU score: 0.03722145753922423
# 197 Don't touch this! no toques esto | BLEU score: 0.03722145753922423
# 198 This is disgusting. esto es repugnante | BLEU score: 0.03722145753922423
# 199 There's no mistake. no hay ningún error | BLEU score: 0.04753271977233425
# 200 Why is that? por qué pasa eso | BLEU score: 0.03701851938020757
# 201 Tom bit me. tom me mordió | BLEU score: 0.03722145753922423
# 202 I love butterflies. me encantan las bodas | BLEU score: 0.10202995073993343
# 203 You weren't funny. no fuisteis graciosos | BLEU score: 0
# 204 That explains everything. eso explica todo | BLEU score: 0.03722145753922423
# 205 No way! ¡de eso nada | BLEU score: 0
# 206 Are you vegetarian? eres tú eres eres eres eres | BLEU score: 0
# 207 Tom's great. tom es genial | BLEU score: 0.03722145753922423
# 208 It's Sunday today. es tu día de hoy | BLEU score: 0.0456496931223525
# 209 Go on in. entra | BLEU score: 0
# 210 This is exhilarating. esto es incoherente | BLEU score: 0.03722145753922423
# 211 You are important. ustedes son importantes | BLEU score: 0
# 212 It was perfect. fue perfecto | BLEU score: 0
# 213 Pull the trigger. bate los dientes | BLEU score: 0
# 214 I needed that. yo necesité eso | BLEU score: 0
# 215 He likes money. le gusta dinero | BLEU score: 0.026670339752046985
# 216 Are they brothers? son hermanos | BLEU score: 0
# 217 I'm already late. ya estoy atrasado | BLEU score: 0
# 218 She stood up. ella se quedó | BLEU score: 0.03722145753922423
# 219 Tom needs help. tom necesita ayuda | BLEU score: 0.03722145753922423
# 220 It's still closed. aún está cerrados | BLEU score: 0.03722145753922423
# 221 I'm home, Tom. soy en casa | BLEU score: 0.026670339752046985
# 222 Tom is wicked. tom está implicado | BLEU score: 0
# 223 They have wine. ellas tienen vino | BLEU score: 0
# 224 Is Tom crazy? tom está loco | BLEU score: 0.03722145753922423
# 225 Shame on you! ¡avergüénzate | BLEU score: 0
# 226 I'm having fun. soy calvo | BLEU score: 0
# 227 We surrendered. lo procuramos | BLEU score: 0
# 228 Tom was horrified. tom fue artero | BLEU score: 0
# 229 I'm absolutely sure! soy absolutamente segura | BLEU score: 0.03722145753922423
# 230 Only Tom knows. sólo sabe tom | BLEU score: 0
# 231 Tom reluctantly left. tom se fue | BLEU score: 0.04000002632824255
# 232 Where's Tom's office? dónde está la oficina de tom | BLEU score: 0.36409302398068727
# 233 Tom drove fast. tom condujo rápido | BLEU score: 0.03722145753922423
# 234 I'm not sick. no estoy enferma | BLEU score: 0.03722145753922423
# 235 You are dreaming. estás muy soñando | BLEU score: 0
# 236 We've altered course. hemos este tornillo | BLEU score: 0
# 237 What's good? qué está bien | BLEU score: 0.03722145753922423
# 238 Don't smoke here. no fume aquí | BLEU score: 0
# 239 Write an answer. escriba una respuesta | BLEU score: 0.03722145753922423
# 240 I love golf. me encantan las bodas | BLEU score: 0
# 241 That's theirs. eso es suya | BLEU score: 0
# 242 Everyone cheered. todos vitorearon | BLEU score: 0
# 243 You're my hero. eres mi héroe | BLEU score: 0.03722145753922423
# 244 Are you satisfied? estáis satisfechos | BLEU score: 0
# 245 I'm twelve. soy imparcial | BLEU score: 0
# 246 We're watching. miramos | BLEU score: 0
# 247 Are you bored? te aburres | BLEU score: 0
# 248 Do you smoke? entendiste | BLEU score: 0
# 249 They will come. van a sal | BLEU score: 0
# 250 Leave him alone. ¡déjame irse | BLEU score: 0
# 251 You're so thin. eres tan delgado | BLEU score: 0
# 252 That's evident. ¡eso es evidente | BLEU score: 0
# 253 You're not stupid. no sos estúpido | BLEU score: 0
# 254 Alcoholism is incurable. las sentamos tienen calor | BLEU score: 0
# 255 Tom helps us. tom ayuda a nosotras | BLEU score: 0
# 256 Appearances are deceiving. las cerezas son rusos | BLEU score: 0
# 257 It's lunch time. es el momento | BLEU score: 0
# 258 I miss it. lo vi | BLEU score: 0
# 259 Look at us. mira allí | BLEU score: 0
# 260 She adores cats. ella adora a los gatos | BLEU score: 0.0444463871528882
# 261 We're defenseless. estamos indefensos | BLEU score: 0
# 262 Isn't that terrific? a que es tremendo | BLEU score: 0
# 263 Answer the question. responde a la pregunta | BLEU score: 0.04753271977233425
# 264 Knock before entering. las vacas dan leche | BLEU score: 0
# 265 That's too personal. esa es una personal | BLEU score: 0.03701851938020757
# 266 It's vibrating. es usted | BLEU score: 0
# 267 They are exhausted. ellos están reventado | BLEU score: 0
# 268 I can't sleep. no puedo dormir | BLEU score: 0.03722145753922423
# 269 That's simple. eso es simple | BLEU score: 0
# 270 Tom is patient. tom está paciente | BLEU score: 0
# 271 They're coming back. ellas están regresando | BLEU score: 0.03722145753922423
# 272 Isn't that terrific? a que es tremendo | BLEU score: 0
# 273 It looks fascinating. se ve fascinante | BLEU score: 0
# 274 You are deranged. eres guapa | BLEU score: 0
# 275 Tom left. tom se fue | BLEU score: 0.03722145753922423
# 276 Tom is right-handed. tom es independiente | BLEU score: 0.03722145753922423
# 277 Here, drink this. toma bébete esto | BLEU score: 0
# 278 Sign this. firma esto | BLEU score: 0
# 279 There's our bus. ¡ahí viene nuestro bus | BLEU score: 0.03701851938020757
# 280 Just take one. cojan solo una | BLEU score: 0.03722145753922423
# 281 I'm your lawyer. soy tu abogado | BLEU score: 0.03722145753922423
# 282 My stomach's full. tengo la panza llena | BLEU score: 0
# 283 It's a gimmick. es un truco | BLEU score: 0.03722145753922423
# 284 Show me. muéstrame cómo | BLEU score: 0
# 285 Hold it! déjalo | BLEU score: 0
# 286 You should exercise. deberías ir de hacer | BLEU score: 0.04753271977233425
# 287 Look it up. búscalo | BLEU score: 0
# 288 I'm begging you. soy muy | BLEU score: 0
# 289 Help yourself, please. ayuda por favor | BLEU score: 0.026670339752046985
# 290 Do you promise? entendiste | BLEU score: 0
# 291 Tom resigned. tom renunció | BLEU score: 0
# 292 What are they? qué son | BLEU score: 0.015071184180845467
# 293 Tom is disagreeable. tom está implicado | BLEU score: 0
# 294 You shouldn't eavesdrop. tú no deberías escuchar a escondidas | BLEU score: 0.09717716588732002
# 295 She trusts him. ella lo perdonó | BLEU score: 0
# 296 I'm fit. soy este | BLEU score: 0
# 297 Speak quietly. habla quedito | BLEU score: 0
# 298 It's almost time. ya casi son momento | BLEU score: 0.03701851938020757
# 299 It's a problem. ese es un problema | BLEU score: 0.04753271977233425
# 300 I have dandruff. yo tengo órdenes | BLEU score: 0
# 301 Tom will go. tom va a ir | BLEU score: 0
# 302 They want this. quiero este | BLEU score: 0
# 303 I'm your friend. soy tu amigo | BLEU score: 0.03722145753922423
# 304 Everybody likes her. todos quieren | BLEU score: 0.005544378814241312
# 305 No one shouted. nadie murió | BLEU score: 0
# 306 Save Tom. ahórrate tomás | BLEU score: 0
# 307 He seems sick. Él se ve enfermo | BLEU score: 0.04753271977233425
# 308 You made it. lo has | BLEU score: 0
# 309 He's a tycoon. Él es ninja | BLEU score: 0
# 310 We'll follow Tom. le daré a tom | BLEU score: 0.028830051881449627
# 311 It smells good! va bien | BLEU score: 0
# 312 Don't fight. no lo cambia | BLEU score: 0
# 313 I'm happy, Tom. soy feliz | BLEU score: 0.015071184180845467
# 314 Smoking stinks. fumar fumar | BLEU score: 0
# 315 That dog jumped. esa perro brincó | BLEU score: 0.03722145753922423
# 316 Where's the toilet? dónde está el servicio | BLEU score: 0.10202995073993343
# 317 It's true. ¡eso es verdad | BLEU score: 0
# 318 I'm your father. soy tu padre | BLEU score: 0.07790941292260128
# 319 I'm very tired. soy muy cansado | BLEU score: 0.03722145753922423
# 320 I was dismissed. yo fue despedido | BLEU score: 0
# 321 Don't be evil. no seas mal | BLEU score: 0.03722145753922423
# 322 I use this. uso esto | BLEU score: 0
# 323 I'm grieving. soy imparcial | BLEU score: 0
# 324 I'll do that. voy a eso | BLEU score: 0
# 325 I'm always happy. soy feliz | BLEU score: 0
# 326 Tom caught Mary. tom lo dijo a mary | BLEU score: 0.037374807627842434
# 327 You're getting closer. tú estás poniendo más calor | BLEU score: 0.0456496931223525
# 328 Follow his example. siga su ejemplo | BLEU score: 0.03722145753922423
# 329 Don't be absurd. no seas absurdo | BLEU score: 0.03722145753922423
# 330 You'll understand someday. vas a entender | BLEU score: 0
# 331 Where's the entrance? dónde queda el ingreso | BLEU score: 0.03701851938020757
# 332 Don't come again. no hagas otra vez | BLEU score: 0
# 333 I'm not yelling. no voy a ser el sordo | BLEU score: 0
# 334 It's very sad. es muy triste | BLEU score: 0.03722145753922423
# 335 Send him in. mándalo dentro | BLEU score: 0
# 336 You're disorganized. eres desorganizado | BLEU score: 0
# 337 I'm already ready. ya estoy lista | BLEU score: 0.03722145753922423
# 338 It's too expensive! es demasiado caro | BLEU score: 0.03722145753922423
# 339 You were lucky. tuviste suerte | BLEU score: 0
# 340 Make way, please. por allí | BLEU score: 0.009141135283858808
# 341 Got it? lo pillas | BLEU score: 0
# 342 You may swim. podéis ir | BLEU score: 0
# 343 Do you understand? entendiste | BLEU score: 0
# 344 We'll be neighbors. seremos asesinados | BLEU score: 0
# 345 I'm running late. voy con retraso | BLEU score: 0.03722145753922423
# 346 We're like family. somos como de familia | BLEU score: 0.03701851938020757
# 347 I must refuse. yo debo esconderme | BLEU score: 0.03722145753922423
# 348 They seem fine. ellos se pusieron guapa | BLEU score: 0
# 349 You're in love. tú estás amor | BLEU score: 0
# 350 I'm horrified. soy imparcial | BLEU score: 0
# 351 Let's stay married. sigamos casados | BLEU score: 0
# 352 I love reading. adoro la leyendo | BLEU score: 0
# 353 Draw a circle. los una zorra | BLEU score: 0
# 354 I will work. yo miré a trabajar | BLEU score: 0.04753271977233425
# 355 Don't believe him. le creas | BLEU score: 0
# 356 It doesn't matter. no importa | BLEU score: 0.015071184180845467
# 357 What's up, dude? qué hay ha fastidiado | BLEU score: 0
# 358 I am disappointed. estoy reventado | BLEU score: 0
# 359 Check your order. comprueba tu buzón | BLEU score: 0
# 360 I talked. esperé | BLEU score: 0
# 361 What's their purpose? cuál es su congresista | BLEU score: 0.10202995073993343
# 362 I'm in danger. soy en peligro | BLEU score: 0.03722145753922423
# 363 We're both fine. los dos estamos en punto | BLEU score: 0.09923912030377631
# 364 Everyone dies eventually. todo el mundo se quedó finalmente | BLEU score: 0.3081980909598119
# 365 They're insane. están molidos de la cabeza | BLEU score: 0.030599904395288136
# 366 Listen to this! escucha a esto | BLEU score: 0
# 367 Stop blaming yourself. deja de torturarte | BLEU score: 0.01369300899911638
# 368 The two laughed. ambos rieron | BLEU score: 0
# 369 Stop complaining. deja de quejarte | BLEU score: 0.03722145753922423
# 370 I'm nervous. estoy nervioso | BLEU score: 0
# 371 I'm kidding. estoy jodiendo | BLEU score: 0
# 372 He helps her. Él ayuda | BLEU score: 0
# 373 I want one! quiero uno | BLEU score: 0
# 374 It's improved. es encantador | BLEU score: 0
# 375 Tom is miserly. tom está implicado | BLEU score: 0
# 376 I wouldn't care. me mal mal | BLEU score: 0.03722145753922423
# 377 Wait, don't shoot! ¡espera no dispares | BLEU score: 0.03722145753922423
# 378 I sat down. me senté | BLEU score: 0
# 379 Take it upstairs. llévalo arriba | BLEU score: 0
# 380 He turned Christian. Él cumplió 13 años | BLEU score: 0
# 381 Tomorrow is Christmas. mañana será navidad | BLEU score: 0
# 382 OK, listen up. ha empezado | BLEU score: 0
# 383 I'm begging you. soy muy | BLEU score: 0
# 384 They demoted you. te degradaron | BLEU score: 0
# 385 No one answered. nadie respondió | BLEU score: 0
# 386 Speak slower, please. habla por favor | BLEU score: 0.01911013349598245
# 387 I'm already busy. ya estoy hasta las manos | BLEU score: 0.0456496931223525
# 388 I threw up. yo odio el teléfono | BLEU score: 0
# 389 I can fly. yo puedo explicar | BLEU score: 0
# 390 So long. tan tan tan tan | BLEU score: 0
# 391 Where's the shovel? dónde está el baño | BLEU score: 0.03701851938020757
# 392 Once more, please. por favor retroceda | BLEU score: 0.01911013349598245
# 393 Bless you. te encuentras | BLEU score: 0
# 394 Tom agreed. tom convino aquiescente | BLEU score: 0
# 395 These are great. estos son genial | BLEU score: 0.03722145753922423
# 396 Don't play dead. no hagas el trabajo | BLEU score: 0.07946100553299702
# 397 Will Tom die? va a tom | BLEU score: 0.026670339752046985
# 398 They are here. ellas ellas están aquí | BLEU score: 0
# 399 They've come back. volvamos | BLEU score: 0
# 400 Is something wrong? está algo mal | BLEU score: 0
# 401 Are they friends? son estadounidenses | BLEU score: 0.015071184180845467
# 402 Tom moved. tom se mudó | BLEU score: 0.03722145753922423
# 403 Tom isn't religious. tom no es creyente | BLEU score: 0.10202995073993343
# 404 Who called me? quién llamó por mí | BLEU score: 0
# 405 It's Saturday today. es sábado | BLEU score: 0.015071184180845467
# 406 They mean business. ellos son bienintencionados | BLEU score: 0
# 407 Nobody's perfect. nadie perfecto | BLEU score: 0
# 408 Tom felt sad. tom se sintió triste | BLEU score: 0.10202995073993343
# 409 He knows everything. sabe todo | BLEU score: 0.009141135283858808
# 410 Today is Wednesday. día de miércoles | BLEU score: 0
# 411 Tom almost drowned. tom casi en las seis | BLEU score: 0.037374807627842434
# 412 Thanks for understanding. gracias por comprenderlo | BLEU score: 0.03722145753922423
# 413 They're under arrest. ellas están detenidos | BLEU score: 0.026670339752046985
# 414 Tom is singing. tom está cantando | BLEU score: 0
# 415 She's rather clueless. ella es bastante guapa | BLEU score: 0.10202995073993343
# 416 You cheated. hiciste trampa | BLEU score: 0
# 417 I hate rules. odio las reglas | BLEU score: 0.03722145753922423
# 418 It's finally over. se acabó | BLEU score: 0.015071184180845467
# 419 That's my car. ese es mi coche | BLEU score: 0.10202995073993343
# 420 I am American. soy americano | BLEU score: 0
# 421 You're a nobody. eres un nadie | BLEU score: 0.03722145753922423
# 422 I love trips. me encantan las bodas | BLEU score: 0.03701851938020757
# 423 Tom started whimpering. tom empezó a la historia | BLEU score: 0.037374807627842434
# 424 Isn't that true? es verdad | BLEU score: 0.009141135283858808
# 425 He walks fast. Él anda rápido | BLEU score: 0
# 426 Wait here. esperad aquí | BLEU score: 0
# 427 I was captured. yo era veloz | BLEU score: 0
# 428 Look out! mira hacia adelante | BLEU score: 0
# 429 I'm very happy. soy muy feliz | BLEU score: 0.03722145753922423
# 430 Close your book. cierra tu libro | BLEU score: 0.03722145753922423
# 431 You'll go far. llegaréis lejos | BLEU score: 0
# 432 I already know. ya puedo | BLEU score: 0
# 433 He's a historian. Él es ninja | BLEU score: 0
# 434 Tom's not breathing. tom no está respirando | BLEU score: 0.04753271977233425
# 435 Don't shout. no interfieras | BLEU score: 0
# 436 Nobody bought it. nadie lo engañes | BLEU score: 0.026670339752046985
# 437 Cross the street. cruza el las bodas | BLEU score: 0
# 438 This is easy. esto es fácil | BLEU score: 0.03722145753922423
# 439 They're in. ellas están dentro | BLEU score: 0
# 440 I do remember. me lo acuerdo | BLEU score: 0
# 441 Someone screamed. alguien gritó | BLEU score: 0
# 442 I'm housesitting. soy guardés | BLEU score: 0
# 443 She trusted you. ella te confiaba en usted | BLEU score: 0.09923912030377631
# 444 Are you blind? eres guapa | BLEU score: 0
# 445 Tom is different. tom es diferente | BLEU score: 0.03722145753922423
# 446 Go on inside. entra | BLEU score: 0
# 447 Water is important. agua es importante | BLEU score: 0.07790941292260128
# 448 They ate marshmallows. ellas comieron bombones | BLEU score: 0
# 449 I'm dancing. estoy bailando | BLEU score: 0
# 450 How's school? cómo te va en el colegio | BLEU score: 0
# 451 See you. hasta la ver | BLEU score: 0
# 452 Has someone died? ha venido alguien | BLEU score: 0
# 453 Who's first? le toca primero | BLEU score: 0
# 454 She smells bad. ella huele mal | BLEU score: 0.03722145753922423
# 455 It's hot here. hace calor aquí | BLEU score: 0.03722145753922423
# 456 Check your inbox. comprueba tu buzón | BLEU score: 0.01911013349598245
# 457 Wake Tom up. despiértate tom | BLEU score: 0
# 458 He's a lawyer. Él es abogado | BLEU score: 0.10873134470594509
# 459 The noise continued. la seguí continuaba | BLEU score: 0
# 460 Who's here? quién está aquí | BLEU score: 0.03722145753922423
# 461 She fell asleep. ella se durmió | BLEU score: 0.03722145753922423
# 462 He enjoyed cycling. Él se puso en se le engañes | BLEU score: 0.03848196746087264
# 463 Come over. veníos | BLEU score: 0
# 464 Read the article. lean el cuchillo | BLEU score: 0.03722145753922423
# 465 There's someone outside. hay alguien afuera | BLEU score: 0.03722145753922423
# 466 Thanks in advance. te agradezco de antemano | BLEU score: 0
# 467 You're great. eres genial | BLEU score: 0
# 468 Atlantis is real. fue real | BLEU score: 0
# 469 Nobody was tortured. nadie fue torturado | BLEU score: 0
# 470 I'll miss Tom. voy a tom | BLEU score: 0.01911013349598245
# 471 It's sweltering. es usted | BLEU score: 0
# 472 Is Tom guilty? es fuera tom | BLEU score: 0.03722145753922423
# 473 Please listen. por favor escucha | BLEU score: 0.03722145753922423
# 474 He trusted you. le confiaba en usted | BLEU score: 0.03701851938020757
# 475 Keep it. ¡continúa | BLEU score: 0
# 476 Let's ask him. mantengámoslo | BLEU score: 0
# 477 I miss it. lo vi | BLEU score: 0
# 478 This bucket leaks. este balde pierde | BLEU score: 0
# 479 I'm from Tokyo. soy de los estados unidos | BLEU score: 0.0456496931223525
# 480 Tom left Mary. tom se fue a mary | BLEU score: 0.037374807627842434
# 481 It's exhilarating. es usted | BLEU score: 0
# 482 I was insulted. yo estaba deprimida | BLEU score: 0
# 483 Come right in. sal | BLEU score: 0
# 484 I eat meat. yo como pan | BLEU score: 0.03722145753922423
# 485 I'm up. estoy reventado | BLEU score: 0
# 486 Business is slow. la empresa es más despacio | BLEU score: 0
# 487 They stopped singing. ellos pararon de cantar | BLEU score: 0.03701851938020757
# 488 Say cheese. di patata | BLEU score: 0
# 489 We've got it. lo hemos | BLEU score: 0
# 490 Isn't it stunning? no es usted aspecto | BLEU score: 0.04753271977233425
# 491 Tom ate quickly. tom comió rápido | BLEU score: 0.03722145753922423
# 492 Let him in. déjenlo entrar | BLEU score: 0
# 493 What's the problem? cuál es el problema | BLEU score: 0.10202995073993343
# 494 They aren't here. ellos no ellas aquí | BLEU score: 0
# 495 You're sleepy. estás cansada | BLEU score: 0
# 496 Tell us more. sé más | BLEU score: 0
# 497 It's sweltering. es usted | BLEU score: 0.015071184180845467
# 498 Open your mouth. ¡abre la boca | BLEU score: 0.03722145753922423
# 499 I'm so alone. estoy tan solo | BLEU score: 0.03722145753922423
# 500 They live apart. viven en el norte | BLEU score: 0.04753271977233425
# 501 We're still investigating. todavía estamos investigando | BLEU score: 0.03722145753922423
# 502 Don't be absurd. no seas absurdo | BLEU score: 0.03722145753922423
# 503 We both laughed. ambos competimos | BLEU score: 0
# 504 Check everyone. comprueba a todos | BLEU score: 0.03722145753922423
# 505 What're you writing? en eres escribir | BLEU score: 0
# 506 Just a minute. solo una momento | BLEU score: 0
# 507 Where's your money? dónde está tu dinero | BLEU score: 0.10202995073993343
# 508 I'm really angry. estoy realmente enfadado | BLEU score: 0.03722145753922423
# 509 Let's move on. sigamos adelante | BLEU score: 0
# 510 Don't bother me. no me molestes | BLEU score: 0.03722145753922423
# 511 Tom was lucky. tom tuvo suerte | BLEU score: 0
# 512 Let's stand up. sigamos adelante | BLEU score: 0
# 513 Tom was terrified. tom estaba aterrorizado | BLEU score: 0.03722145753922423
# 514 Tom should've known. tom debía haber sabido | BLEU score: 0
# 515 There's no coffee. hace falta café | BLEU score: 0
# 516 You're something else. eres la bomba | BLEU score: 0
# 517 Come anytime. sal en serio | BLEU score: 0
# 518 We'll see. nosotros estamos a la escucha | BLEU score: 0
# 519 They were shorthanded. estaban faltos de personal | BLEU score: 0.03701851938020757
# 520 You're the boss. eres el jefe | BLEU score: 0.07790941292260128
# 521 Maybe it'll snow. puede que nieve | BLEU score: 0
# 522 There's nothing here. aquí hay nada | BLEU score: 0.07790941292260128
# 523 We're coming. nos estamos viniendo | BLEU score: 0
# 524 You missed. tú te extrañé | BLEU score: 0
# 525 I've gained weight. he comido | BLEU score: 0
# 526 Tom is embarrassed. tomás está avergonzado | BLEU score: 0.03722145753922423
# 527 Time for dinner. es hora de comer | BLEU score: 0.10202995073993343
# 528 Who cheered? quién fue el que vitoreó | BLEU score: 0
# 529 I don't steal. yo no puedo comer | BLEU score: 0.04753271977233425
# 530 He is old. Él es viejo | BLEU score: 0.10873134470594509
# 531 You're not God. no sos dios | BLEU score: 0.03722145753922423
# 532 Is he right? ha acertado | BLEU score: 0
# 533 They know you. te conocen | BLEU score: 0
# 534 I was dreaming. estaba soñando | BLEU score: 0
# 535 Aren't you hot? tú estás sin calor | BLEU score: 0
# 536 Tom is guilty. tom es culpable | BLEU score: 0.03722145753922423
# 537 Is Tom here? está aquí tom | BLEU score: 0
# 538 Please sit here. por favor siéntate aquí | BLEU score: 0.03701851938020757
# 539 This is nice. esto está bien | BLEU score: 0
# 540 Remember this rule. recuerda esto | BLEU score: 0
# 541 It doesn't exist. va a ser existe | BLEU score: 0
# 542 He finally arrived. Él finalmente llegó | BLEU score: 0.03171655779267419
# 543 You're new here. estáis aquí | BLEU score: 0
# 544 I'm anorexic. soy imparcial | BLEU score: 0
# 545 Tom, don't leave. tom no vayas | BLEU score: 0
# 546 The rain stopped. dejó de llover | BLEU score: 0
# 547 Tom shed tears. tom parece exhausto | BLEU score: 0
# 548 They stopped kissing. ellos pararon de besarse | BLEU score: 0.03701851938020757
# 549 Everyone's reading. todo el mundo leyendo | BLEU score: 0
# 550 Do the dishes. ¡qué los cordones | BLEU score: 0.03722145753922423
# 551 Tom is coming. tom va a viniendo | BLEU score: 0
# 552 She fascinated me. ella me fascinaba | BLEU score: 0.03722145753922423
# 553 Help yourself. sírvete tú mismo | BLEU score: 0
# 554 Stop gossiping. deja de quejarte | BLEU score: 0.03722145753922423
# 555 How's your brother? cómo está tu hermano | BLEU score: 0.10202995073993343
# 556 You're my friend. sos mi amiga | BLEU score: 0.03722145753922423
# 557 I mean it. hablo en serio | BLEU score: 0.026670339752046985
# 558 We're doing nothing. la guerra no lo hizo nada | BLEU score: 0
# 559 Come back here. sal de aquí | BLEU score: 0
# 560 Tom is wet. tom está mojada | BLEU score: 0.03722145753922423
# 561 I'm expecting visitors. soy intolerante a los extranjeros | BLEU score: 0
# 562 Are you coming? te va bien | BLEU score: 0
# 563 Please sit down. por favor siéntese | BLEU score: 0.03722145753922423
# 564 He's always joking. siempre está bromeando | BLEU score: 0.03722145753922423
# 565 Everybody loves her. todos la aman | BLEU score: 0.01911013349598245
# 566 Are they brothers? son hermanos | BLEU score: 0
# 567 Who are they? quién son | BLEU score: 0.015071184180845467
# 568 Keep your promises. seguí tu tipo | BLEU score: 0
# 569 Call us. sé nuestra | BLEU score: 0
# 570 Tom seemed shy. tomás parecía tímido | BLEU score: 0.03722145753922423
# 571 This is good. esto está bien | BLEU score: 0
# 572 He's my husband. Él es mi marido | BLEU score: 0.261698736230754
# 573 Tom was innocent. tom fue inocente | BLEU score: 0
# 574 It's Tom's job. es el trabajo de tom | BLEU score: 0.030599904395288136
# 575 Tom got excited. tom se emocionado | BLEU score: 0.03722145753922423
# 576 What motivates you? qué tal a usted | BLEU score: 0
# 577 She helped him. ella le ayudó | BLEU score: 0.03722145753922423
# 578 Did Tom help? ayudaste a tom | BLEU score: 0
# 579 Nightmares are scary. somos profesores | BLEU score: 0
# 580 Tom was singing. tom estaba cantando | BLEU score: 0.03722145753922423
# 581 She adores him. ella lo adora | BLEU score: 0.03722145753922423
# 582 The river overflowed. el río se desbordó | BLEU score: 0.0481955361073579
# 583 That's not true. eso no es cierto | BLEU score: 0.10202995073993343
# 584 We volunteered. nos morimos de voluntario | BLEU score: 0
# 585 I like camels. me gusta la luz de las velas | BLEU score: 0
# 586 I'm just asking. soy sólo | BLEU score: 0
# 587 Tom felt relieved. tom se sintió aliviado | BLEU score: 0.10202995073993343
# 588 We're back. hemos vuelto | BLEU score: 0
# 589 I'm unemployed. estoy desempleada | BLEU score: 0
# 590 I lost consciousness. me perdido la perdido | BLEU score: 0.04753271977233425
# 591 We searched everywhere. estábamos en todas partes | BLEU score: 0
# 592 I'm eating now. ahora soy comiendo | BLEU score: 0.03722145753922423
# 593 Let's shake hands. sigamos adelante | BLEU score: 0
# 594 Wait a moment. espera un segundo | BLEU score: 0.03722145753922423
# 595 You've done it! ya has hecho | BLEU score: 0
# 596 Write that down. anoten eso | BLEU score: 0
# 597 Who sells this? quién vende esto | BLEU score: 0.03722145753922423
# 598 We study French. estábamos francés | BLEU score: 0
# 599 Close that door. cierra eso | BLEU score: 0
# 600 Are you famous? eres desmemoriado | BLEU score: 0.015071184180845467
# 601 She spoke rapidly. ella habló en silencio | BLEU score: 0.04753271977233425
# 602 I was right. tuve suerte | BLEU score: 0
# 603 We'll go together. vamos a juntos | BLEU score: 0.026670339752046985
# 604 We're hungry. estamos hambrientos | BLEU score: 0
# 605 I'll stay home. me voy a casa | BLEU score: 0.061884293332739315
# 606 The bridge collapsed. el puente se derrumbó | BLEU score: 0.07946100553299702
# 607 I wasn't trapped. yo no estaba atrapado | BLEU score: 0.04753271977233425
# 608 Stop deluding yourself. deja de ti mismo | BLEU score: 0.026701109166326675
# 609 Coffee, please. café por favor | BLEU score: 0.03722145753922423
# 610 The money disappeared. dinero dinero | BLEU score: 0.015071184180845467
# 611 It tasted sweet. fue los dulce | BLEU score: 0
# 612 Take a card. echa una carta | BLEU score: 0.03722145753922423
# 613 Who's speaking? quién va a quién | BLEU score: 0
# 614 You are hopeless. ustedes son inútil | BLEU score: 0
# 615 Who wants cookies? quién quiere ha pasado | BLEU score: 0.04753271977233425
# 616 We're studying French. estamos estudiando francés | BLEU score: 0.03722145753922423
# 617 It's your choice. tú decides | BLEU score: 0
# 618 It's nice. es agradable | BLEU score: 0
# 619 He's in prison. Él está en te agradezco de antemano | BLEU score: 0.19308506685901675
# 620 When was that? eso fue eso | BLEU score: 0.03722145753922423
# 621 That's fascinating. así es fascinante | BLEU score: 0.03722145753922423
# 622 Don't disappoint me. no me decepciones | BLEU score: 0.03722145753922423
# 623 About what time? casi lo que se momento | BLEU score: 0
# 624 Monday's not good. la lunes no está ahí | BLEU score: 0.08125011970110721
# 625 I am good. soy reventado | BLEU score: 0
# 626 Tom is intolerant. tom es va a la lactosa | BLEU score: 0.03759340464156993
# 627 I've had enough. ya estoy suficiente | BLEU score: 0
# 628 He takes vitamins. Él habla en toma | BLEU score: 0.056526248548690414
# 629 Keep smiling. continuad sonriendo | BLEU score: 0
# 630 She's unbelievably naive. ella ella ella ella ella | BLEU score: 0
# 631 I'm motivated. estoy motivado | BLEU score: 0
# 632 I'm a student. soy maderero | BLEU score: 0
# 633 She's very beautiful. ella es muy guapa | BLEU score: 0.04753271977233425
# 634 I'm so unlucky! estoy tan tan tan tan tan tan | BLEU score: 0.03235934848975789
# 635 Look at us. mira allí | BLEU score: 0
# 636 Who's laughing now? quién se está riendo | BLEU score: 0.03701851938020757
# 637 Call me. llámame en la llámame | BLEU score: 0
# 638 We were stranded. estábamos recién colgados | BLEU score: 0
# 639 Tom recovered. tom va a tomás | BLEU score: 0
# 640 You can go. puedes irte | BLEU score: 0
# 641 He looks young. Él luce joven | BLEU score: 0.026670339752046985
# 642 I'm getting married. voy a casar | BLEU score: 0.07790941292260128
# 643 This is broken. esto está descompuesto | BLEU score: 0.03722145753922423
# 644 Weren't they satisfied? no estabas satisfecho | BLEU score: 0
# 645 Say it clearly. dilo claramente | BLEU score: 0
# 646 Tom sang softly. tom cantó suavemente | BLEU score: 0.01911013349598245
# 647 My head aches. me duele la espalda | BLEU score: 0.10202995073993343
# 648 He is overconfident. es soberbio | BLEU score: 0
# 649 It's started already. ya empezó | BLEU score: 0
# 650 Please fix that. por favor arreglá eso | BLEU score: 0.044022686633808955
# 651 Don't bother me. no me molestes | BLEU score: 0.01911013349598245
# 652 I've been shot. he estado disparó | BLEU score: 0
# 653 Don't ask. yo hagas preguntas | BLEU score: 0
# 654 Many fish died. esa murió murió | BLEU score: 0
# 655 You're very perceptive. eres muy práctico | BLEU score: 0.03722145753922423
# 656 Tom is smoking. tomás está fumar | BLEU score: 0.03722145753922423
# 657 Drink something. tómate algo | BLEU score: 0
# 658 I am better. soy viejo | BLEU score: 0
# 659 See you Monday. los vemos lunes | BLEU score: 0
# 660 Watch closely. vigila atentamente | BLEU score: 0
# 661 You're very smart. eres muy lista | BLEU score: 0.03722145753922423
# 662 I resigned. recomiendo de acuerdo | BLEU score: 0
# 663 This one's different. este es una diferente | BLEU score: 0.04753271977233425
# 664 Enjoy your meal. ¡buen provecho | BLEU score: 0
# 665 We're losing it. lo estamos perdiendo | BLEU score: 0.03722145753922423
# 666 Humor Tom. ayuda a tom | BLEU score: 0.03722145753922423
# 667 Tom is short. tom es corta | BLEU score: 0.03722145753922423
# 668 They are Christians. ellos son cristianos | BLEU score: 0
# 669 Tom apologized. tom ustedes repugnante | BLEU score: 0
# 670 Rules are rules. reglas | BLEU score: 0.0024787521766663585
# 671 I hate French. odio el francés | BLEU score: 0.03722145753922423
# 672 Tom's in there. tom está ahí | BLEU score: 0.03722145753922423
# 673 It looked cheap. fue mi eso | BLEU score: 0
# 674 Things happen. las cosas cambiaron | BLEU score: 0.03722145753922423
# 675 Tom was inconsiderate. tom fue despedido | BLEU score: 0.03722145753922423
# 676 Come back tomorrow. venga mañana | BLEU score: 0
# 677 You are lazy! eres muy perezoso | BLEU score: 0
# 678 Tie your shoelaces. Átate los cordones | BLEU score: 0.10873134470594509
# 679 You betrayed us. nos traicionaste | BLEU score: 0
# 680 Are you new? eres nueva | BLEU score: 0
# 681 Tom's deaf. tom está acaso | BLEU score: 0
# 682 Let's go down. ¡Órale | BLEU score: 0
# 683 They'll be fine. eso va bien | BLEU score: 0
# 684 We're all dying. nos estamos muriendo | BLEU score: 0.03722145753922423
# 685 Hold my calls. espere mi cuenta | BLEU score: 0
# 686 He's faking. Él es va a los hipócritas | BLEU score: 0
# 687 Have another. tomá otro | BLEU score: 0
# 688 They live nearby. viven allá | BLEU score: 0.015071184180845467
# 689 Stay here. mantente aquí | BLEU score: 0
# 690 It won't hurt. no sabrá | BLEU score: 0
# 691 Tom fell asleep. tom se durmió | BLEU score: 0.026670339752046985
# 692 We were unsuccessful. estábamos recién somos | BLEU score: 0
# 693 Tom likes me. tom le quiere a mí | BLEU score: 0
# 694 I'll stay home. me voy a casa | BLEU score: 0
# 695 Stand aside! ¡dejad sitio | BLEU score: 0
# 696 Sign this. firma esto | BLEU score: 0
# 697 He is cranky. Él está inconsciente | BLEU score: 0
# 698 Tom loves architecture. tom ama a los le encantan | BLEU score: 0.026936851496754878
# 699 I wasn't frightened. yo no asustado | BLEU score: 0
# 700 We are young. somos profesores | BLEU score: 0
# 701 What's gone wrong? cuál se ha mal | BLEU score: 0
# 702 They are pretty. ellos son guapa | BLEU score: 0.03722145753922423
# 703 Seize him! le él por él | BLEU score: 0
# 704 Tom was executed. tom fue artero | BLEU score: 0.03722145753922423
# 705 What's in here? qué hay aquí | BLEU score: 0.03722145753922423
# 706 Mary is hysterical. mary es zurda | BLEU score: 0
# 707 They're foreigners. están arruinados | BLEU score: 0
# 708 Tom isn't stupid. tom no estúpido | BLEU score: 0.026670339752046985
# 709 Are they gone? por favor fueron | BLEU score: 0
# 710 Take precautions. ¡cuidate | BLEU score: 0
# 711 Tom looked scared. tom tenía miedo | BLEU score: 0
# 712 Make it happen. hazlo tú lo suceder | BLEU score: 0
# 713 Who would care? quién es nuestro hogar | BLEU score: 0.03701851938020757
# 714 Be careful. tengan cuidado | BLEU score: 0
# 715 He is kind. Él es gentil | BLEU score: 0.10873134470594509
# 716 He is nasty. Él es repugnante | BLEU score: 0.03722145753922423
# 717 You're my enemy. sos mi enemiga | BLEU score: 0
# 718 Don't smoke. no fume fumar | BLEU score: 0
# 719 Stop dreaming. deja de soñar | BLEU score: 0.03722145753922423
# 720 It's nice today. es guapa | BLEU score: 0
# 721 I like cooking. me gusta cocinar | BLEU score: 0.03722145753922423
# 722 Break it down. rómpelo | BLEU score: 0
# 723 Don't drink anything. no bebe nada | BLEU score: 0
# 724 Tom is ready. tom está lista | BLEU score: 0.03722145753922423
# 725 You're clever. eres inteligente | BLEU score: 0
# 726 I'm keeping count. soy cuente la cuenta | BLEU score: 0.03701851938020757
# 727 That worked well. eso funcionó | BLEU score: 0.015071184180845467
# 728 They trusted Tom. ellos confiaron en tom | BLEU score: 0.04753271977233425
# 729 Respect yourself. ¡modérese usted | BLEU score: 0
# 730 Nothing lasts forever. nada es para siempre | BLEU score: 0.03701851938020757
# 731 That's pathetic. eso es patético | BLEU score: 0.03722145753922423
# 732 This is weird. esto es raro | BLEU score: 0.03722145753922423
# 733 Tom lacks discipline. tom carece de disciplina | BLEU score: 0
# 734 They deserve respect. ellos cenaron | BLEU score: 0
# 735 I'm very clumsy. soy muy gorda | BLEU score: 0.03722145753922423
# 736 We're all students. somos inquietos | BLEU score: 0.015071184180845467
# 737 Tom is unreliable. tom es poco fiable | BLEU score: 0.028830051881449627
# 738 He is eating. Él está comiendo | BLEU score: 0
# 739 Grab Tom. agarra fuertemente | BLEU score: 0
# 740 That won't happen. eso no va a pasar | BLEU score: 0.0456496931223525
# 741 Tom casually shrugged. tom parece exhausto | BLEU score: 0
# 742 Go away. ¡vete ya | BLEU score: 0
# 743 Tom resumed reading. tom siguió leyendo | BLEU score: 0
# 744 Get well soon! ¡que te mejores | BLEU score: 0.07790941292260128
# 745 We cultivate rice. comprendemos esto | BLEU score: 0
# 746 I like women. me gusta las mujeres | BLEU score: 0.03701851938020757
# 747 The soldiers fired. la cortina despedido | BLEU score: 0
# 748 Try harder tomorrow. prueba mañana con más ganas | BLEU score: 0.20076743255187193
# 749 I'm not poor. no voy a pobre | BLEU score: 0
# 750 She woke up. ella lo has vuelto | BLEU score: 0
# 751 Mary's my niece. el favor tengo mi chaval | BLEU score: 0.037374807627842434
# 752 I like wine. me gusta vino | BLEU score: 0.026670339752046985
# 753 How annoying! ¡qué rollo | BLEU score: 0
# 754 Spiders scare me. me das miedo | BLEU score: 0.01911013349598245
# 755 I'm not bald. no estoy calvo | BLEU score: 0
# 756 I love you. te encantan las ama | BLEU score: 0
# 757 You may look. puedes mirar | BLEU score: 0
# 758 I'm patient. tengo paciencia | BLEU score: 0
# 759 I said stop. yo dije que alto | BLEU score: 0.03701851938020757
# 760 You're really wonderful. eres realmente maravillosa | BLEU score: 0.03722145753922423
# 761 Tom already knows. tom ya sabe | BLEU score: 0.03722145753922423
# 762 Tom despised Mary. tom abandonó a mary | BLEU score: 0.03701851938020757
# 763 Watch us. déjanos | BLEU score: 0
# 764 Boston is overrated. boston es boston | BLEU score: 0
# 765 Make an appointment. solicite una cita | BLEU score: 0.03722145753922423
# 766 Everything changed. todo cambiará | BLEU score: 0
# 767 Don't be silly. no seas boludo | BLEU score: 0.03722145753922423
# 768 He can't count. Él no puede conmigo | BLEU score: 0.10202995073993343
# 769 We've been spotted. hemos estado tan arrastrado | BLEU score: 0
# 770 Can we go? podemos ir | BLEU score: 0
# 771 Is he satisfied? ella está satisfecha | BLEU score: 0
# 772 The attempt failed. la empresa se puso fracasó | BLEU score: 0
# 773 Please copy this. por favor copiad esto | BLEU score: 0
# 774 Tom isn't thrilled. tom no está emocionado | BLEU score: 0.10202995073993343
# 775 It's not logical. no es natural | BLEU score: 0.03722145753922423
# 776 I drank milk. tomé leche | BLEU score: 0
# 777 I'm a hero. soy maderero | BLEU score: 0
# 778 Life ain't easy. la vida es fácil | BLEU score: 0.03428490282331748
# 779 They're waiting. están esperando | BLEU score: 0
# 780 We're back. hemos vuelto | BLEU score: 0
# 781 I fell. yo me dormí | BLEU score: 0
# 782 Tom scares me. tom me abandonó | BLEU score: 0.03722145753922423
# ...
# 1608 Leave tomorrow. prueba mañana | BLEU score: 0
# 1609 I'm your friend. soy tu amigo | BLEU score: 0.03722145753922423
# 1610 I'm selfish. soy egoísta | BLEU score: 0
# 1611 Come early. venga temprano | BLEU score: 0
# 1612 I'm undressing. me soy sacando la ropa | BLEU score: 0
# 1613 Watch closely. vigila atentamente | BLEU score: 0
# 1614 It's a curse. es un mojigato | BLEU score: 0
# 1615 Don't get drunk. no se estaba borracho | BLEU score: 0
# 1616 I've got beer. estoy con diarrea | BLEU score: 0
# 1617 Walk this way. ven por aquí | BLEU score: 0.03722145753922423
# 1618 Go away! ¡vete ya | BLEU score: 0
# 1619 Go to sleep. vete a dormir | BLEU score: 0.03722145753922423
# 1620 He loves her. le gusta ella | BLEU score: 0
# 1621 Come and look. pareces y observad | BLEU score: 0.03722145753922423
# 1622 Happy Thanksgiving! feliz | BLEU score: 0
# 1623 We're gullible. somos ingenuos | BLEU score: 0
# 1624 Stop reading. deja de leer | BLEU score: 0.03722145753922423
# 1625 She is awkward. ella es gentil | BLEU score: 0.03722145753922423
# 1626 Can you walk? podéis andar | BLEU score: 0
# 1627 Tom outwitted Mary. tom le burlé a mary | BLEU score: 0
# 1628 We must evacuate. tenemos que evacuar | BLEU score: 0
# 1629 You're safe now. ahora están a salvo | BLEU score: 0.03701851938020757
# 1630 Can you whistle? puedes dormir | BLEU score: 0
# 1631 Don't stop here. no paren aquí | BLEU score: 0
# 1632 You're reliable. eres simpático | BLEU score: 0
# 1633 What a shame! ¡qué lástima | BLEU score: 0
# 1634 What an idea! ¡qué ego | BLEU score: 0
# 1635 You're always singing. deja de cantar | BLEU score: 0
# 1636 I needed this. yo necesitaba esto | BLEU score: 0
# 1637 Hey, come here. oiga venga aquí | BLEU score: 0
# 1638 Say cheese. di patata | BLEU score: 0
# 1639 It's not Christmas. no es natural | BLEU score: 0.03722145753922423
# 1640 Tom skipped lunch. tom perdonó a traer almuerzo | BLEU score: 0
# 1641 It's for you. es usted | BLEU score: 0.009141135283858808
# 1642 What are these? qué son éstas | BLEU score: 0.03722145753922423
# 1643 Tom looks winded. tom parece exhausto | BLEU score: 0.026670339752046985
# 1644 That's obvious. es obvio | BLEU score: 0
# 1645 You know something. tú conoces algo | BLEU score: 0
# 1646 It's easy money. es bastante dinero | BLEU score: 0.03722145753922423
# 1647 Money talks. hace falta dinero | BLEU score: 0
# 1648 Tom likes money. a tom le gusta la dinero | BLEU score: 0.06963048203108795
# 1649 I can sing. yo puedo correr | BLEU score: 0
# 1650 Do fish sleep? lo dormir | BLEU score: 0
# 1651 I'm on holiday. soy de vacaciones | BLEU score: 0.03722145753922423
# 1652 I contributed. yo ayudó | BLEU score: 0
# 1653 What nonsense! qué pasaría | BLEU score: 0
# 1654 It's Tom's office. es la oficina de tom | BLEU score: 0.3670124608961283
# 1655 My sunburn hurts. me duele el estómago | BLEU score: 0.03701851938020757
# 1656 He doesn't tan. Él no va a entender | BLEU score: 0.08125011970110721
# 1657 They helped Tom. estaban ayudó a tom | BLEU score: 0.03701851938020757
# 1658 Tom remembered. tomás se acordó | BLEU score: 0
# 1659 I'm making dinner. soy la cena | BLEU score: 0.026670339752046985
# 1660 I feel helpless. me siento inútil | BLEU score: 0.03722145753922423
# 1661 Tom agrees. tom va a tom | BLEU score: 0
# 1662 Write Tom. escribe a tom | BLEU score: 0.03722145753922423
# 1663 Mom's working. seguí trabajando | BLEU score: 0
# 1664 It's my brother's. es mi hermano | BLEU score: 0.026670339752046985
# 1665 Isn't everything beautiful? acaso es bello | BLEU score: 0.07790941292260128
# 1666 You're so stubborn. eres tan predecible | BLEU score: 0
# 1667 It takes time. toma tiempo | BLEU score: 0
# 1668 We continued chatting. fuimos escéptico | BLEU score: 0
# 1669 I feel useless. yo me siento mal | BLEU score: 0.04753271977233425
# 1670 Have a drink. tómate algo | BLEU score: 0
# 1671 Is it safe? es grave | BLEU score: 0
# 1672 They live there. viven allá | BLEU score: 0.015071184180845467
# 1673 I need help. yo necesito ayuda | BLEU score: 0
# 1674 Stop showing off! deja de nuevo | BLEU score: 0.03722145753922423
# 1675 How beautiful! ¡qué guapa | BLEU score: 0
# 1676 It wasn't hard. yo no fue difícil | BLEU score: 0
# 1677 Tom understood. tom comprendió | BLEU score: 0
# 1678 Beware of imitations. ojo con las imitaciones | BLEU score: 0.10202995073993343
# 1679 I saw one. vi a uno | BLEU score: 0
# 1680 Tom changed. tom cambió de cambiado | BLEU score: 0
# 1681 Money isn't everything. hace falta todo | BLEU score: 0
# 1682 I'll wait. lo esperé | BLEU score: 0
# 1683 Isn't it black? no es negra | BLEU score: 0.07790941292260128
# 1684 We're cousins. somos primos | BLEU score: 0
# 1685 Tom's sick. tom está enfermo | BLEU score: 0.03722145753922423
# 1686 We're through. hemos terminado | BLEU score: 0
# 1687 Get ready. salte | BLEU score: 0
# 1688 Tom waited calmly. tom esperó con calma | BLEU score: 0.10202995073993343
# 1689 Well done, guys. vamos a necesitar refugio | BLEU score: 0
# 1690 Be brief. sé breve | BLEU score: 0
# 1691 Isn't that mine? es la mía | BLEU score: 0.03722145753922423
# 1692 I'd ask Tom. yo pregúntale a tom | BLEU score: 0.028830051881449627
# 1693 Go on ahead. adelante | BLEU score: 0
# 1694 I admired Tom. yo creo a tom | BLEU score: 0.03701851938020757
# 1695 You're surrounded. estás vieja | BLEU score: 0
# 1696 I'm thinking. estoy meditando | BLEU score: 0
# 1697 Tom loved animals. a tom le gustan los animales | BLEU score: 0.03784310341709043
# 1698 I'm educated. soy imparcial | BLEU score: 0
# 1699 Tom corrected himself. tom se quedó sin techo | BLEU score: 0.0456496931223525
# 1700 It's beyond reason. es bastante mal | BLEU score: 0
# 1701 Keep smiling. continuad sonriendo | BLEU score: 0
# 1702 I need water. yo necesito agua | BLEU score: 0
# 1703 You understand, right? lo has en lo cierto | BLEU score: 0
# 1704 That's her. ella ella ella ella ella ella | BLEU score: 0
# 1705 You look pleased. pareces aburrido | BLEU score: 0
# 1706 These are Tom's. estos son de tom | BLEU score: 0.10202995073993343
# 1707 You're always working. siempre estás trabajando | BLEU score: 0.03722145753922423
# 1708 He doesn't sleep. Él no va a dormir | BLEU score: 0
# 1709 He can't sing. Él no sabe cantar | BLEU score: 0
# 1710 It's alive. es vivo | BLEU score: 0
# 1711 Be confident. sé confiado | BLEU score: 0
# 1712 He was patient. Él le paciente | BLEU score: 0.03722145753922423
# 1713 Nothing's working. papá está trabajando | BLEU score: 0
# 1714 You always sing. usted siempre canta | BLEU score: 0
# 1715 It's very difficult. es muy difícil | BLEU score: 0.03722145753922423
# 1716 Write everything down. anota todo | BLEU score: 0
# 1717 I like honey. me gusta la miel | BLEU score: 0.10202995073993343
# 1718 You're the expert. tú eres el experto | BLEU score: 0
# 1719 This is ridiculous. es increíble | BLEU score: 0.015071184180845467
# 1720 The clock ticked. el telón se puso claro | BLEU score: 0
# 1721 He's not ready. Él no está listo | BLEU score: 0.261698736230754
# 1722 Business is business. han mejorado | BLEU score: 0
# 1723 You're an angel. ¡eres un ángel | BLEU score: 0.03722145753922423
# 1724 Now I'm sad. ahora pon triste | BLEU score: 0
# 1725 She likes tigers. a ella le gustan los tigres | BLEU score: 0.09717716588732002
# 1726 I'll call him. lo llamaré | BLEU score: 0
# 1727 They're insane. están molidos de la cabeza | BLEU score: 0
# 1728 Hi, guys. qué tal os va | BLEU score: 0
# 1729 I'm a teacher. yo soy profesor | BLEU score: 0
# 1730 We're not rich. somos profesores | BLEU score: 0.015071184180845467
# 1731 We study music. estábamos guapa | BLEU score: 0
# 1732 It's too soon. hace demasiado tarde | BLEU score: 0.03722145753922423
# 1733 Are you brothers? son hermanos | BLEU score: 0
# 1734 I'm going bald. voy a calvo | BLEU score: 0
# 1735 Silence is golden. el silencio es oro | BLEU score: 0
# 1736 Tom is wicked. tom está implicado | BLEU score: 0
# 1737 Louder, please. le por favor | BLEU score: 0.026670339752046985
# 1738 You shouldn't go. por preguntarme ahí | BLEU score: 0
# 1739 I'm losing patience. soy perdiendo le gusta perder | BLEU score: 0.037374807627842434
# 1740 I love it. lo adoro | BLEU score: 0
# 1741 You're the scapegoat. eres el chivo expiatorio | BLEU score: 0.028830051881449627
# 1742 Don't be evil. no seas mal | BLEU score: 0
# 1743 Tom likes her. a tom le gusta ella | BLEU score: 0.08991803844670224
# 1744 Come help me. ayúdame | BLEU score: 0
# 1745 Speak softly. habla más fuerte | BLEU score: 0
# 1746 See you around. los vemos alrededor | BLEU score: 0
# 1747 It looks strange. va a extraño | BLEU score: 0
# 1748 Is he sleeping? está durmiendo | BLEU score: 0
# 1749 Everyone loves sports. todos aman a los deportes | BLEU score: 0.029793304282441858
# 1750 These are great. estos son genial | BLEU score: 0.03722145753922423
# 1751 Is Tom famous? tom es famoso | BLEU score: 0.03722145753922423
# 1752 I'm yours. soy suyo | BLEU score: 0
# 1753 We hate violence. comprendemos esto | BLEU score: 0
# 1754 Please say something. por favor decí algo | BLEU score: 0
# 1755 That's amazing! ¡eso es increíble | BLEU score: 0
# 1756 What's happening? qué pasa | BLEU score: 0
# 1757 I'm drunk. estoy borracho | BLEU score: 0
# 1758 I knew Tom. lo sabía | BLEU score: 0
# 1759 I recognize him. lo conozco | BLEU score: 0
# 1760 I hate winter. odio el invierno | BLEU score: 0.03722145753922423
# 1761 They're alone. están solo | BLEU score: 0
# 1762 Move on, Tom. prosigue tom | BLEU score: 0
# 1763 Cold water, please. frío hace frío por favor | BLEU score: 0.037374807627842434
# 1764 Remain seated, please. quedaos sentados por favor | BLEU score: 0.03701851938020757
# 1765 Who won today? quién ganó a día de hoy | BLEU score: 0
# 1766 Whose is this? de quién es esto | BLEU score: 0.10202995073993343
# 1767 I'm not here. no voy aquí | BLEU score: 0.026670339752046985
# 1768 We're all invited. estamos todos invitadas | BLEU score: 0.03722145753922423
# 1769 Get in here! aquí | BLEU score: 0
# 1770 French is difficult. es francés | BLEU score: 0.010870703118767311
# 1771 Let's eat sushi. comamos | BLEU score: 0
# 1772 He finished breakfast. Él terminó el desayuno | BLEU score: 0.10202995073993343
# 1773 She said goodbye. ella dijo chao | BLEU score: 0.03722145753922423
# 1774 I'm freaking out. soy fuera | BLEU score: 0
# 1775 Don't sass me. no me sermonees | BLEU score: 0
# 1776 I hate sand. odio la arena | BLEU score: 0.07790941292260128
# 1777 He isn't married. Él no va a casada | BLEU score: 0.09923912030377631
# 1778 Tom wants children. tom quiere a niños | BLEU score: 0.04753271977233425
# 1779 They know him. lo hicieron | BLEU score: 0.015071184180845467
# 1780 Be objective. sean objetivos | BLEU score: 0
# 1781 Tom answered. tom respondió | BLEU score: 0
# 1782 I'll be going. voy a ir | BLEU score: 0.07790941292260128
# 1783 He is bankrupt. Él es va | BLEU score: 0.03722145753922423
# 1784 Are you Tom? tú eres tom | BLEU score: 0
# 1785 Stand up, please. por favor date mi favor | BLEU score: 0.030599904395288136
# 1786 We're twins. somos gemelos | BLEU score: 0
# 1787 Stop right here. párate aquí mismo | BLEU score: 0
# 1788 Adjust the brakes. ¡qué los estados unidos | BLEU score: 0.04753271977233425
# 1789 Count me in. cuenta conmigo | BLEU score: 0
# 1790 I'm just joking. es sólo una broma | BLEU score: 0
# 1791 Tom apologized again. tom volvió a preguntar | BLEU score: 0.07946100553299702
# 1792 Tom's Canadian. tom es canadiense | BLEU score: 0.03722145753922423
# 1793 Who phoned? quién va a quién | BLEU score: 0
# 1794 We're ambidextrous. somos ambidiestros | BLEU score: 0
# 1795 Never say never. nunca hay que decir | BLEU score: 0
# 1796 I'm a farmer. soy maderero | BLEU score: 0
# 1797 It is second-hand. es maravilloso | BLEU score: 0
# 1798 Tom writes slowly. tom escribe lentamente | BLEU score: 0.03722145753922423
# 1799 Tom is furious. tom está sólo | BLEU score: 0.03722145753922423
# 1800 They're insane. están molidos de la cabeza | BLEU score: 0
# 1801 Tom came early. tom subió temprano | BLEU score: 0
# 1802 I have time. gané | BLEU score: 0
# 1803 I like clocks. me gusta la luz de las velas | BLEU score: 0
# 1804 You look awful. pareces aburrido | BLEU score: 0
# 1805 I require advice. yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo | BLEU score: 0
# 1806 Are you sure? está segura | BLEU score: 0
# 1807 Everybody's dead. todos muerto | BLEU score: 0
# 1808 Stay close. mantente cerca | BLEU score: 0
# 1809 That's my book. esa es mi libro | BLEU score: 0.10202995073993343
# 1810 Some fish fly. algo se me hizo tarde | BLEU score: 0
# 1811 He was cheating. Él estaba trampas | BLEU score: 0
# 1812 Does everybody understand? lo hace | BLEU score: 0
# 1813 I ate it. lo conozco | BLEU score: 0
# 1814 Tom's my cousin. tom es mi héroe | BLEU score: 0.10202995073993343
# 1815 I'm not short. no soy pequeño | BLEU score: 0.03722145753922423
# 1816 What for? qué sirve | BLEU score: 0
# 1817 You're cute. estás tan gordo | BLEU score: 0
# 1818 He got angry. Él se enojó | BLEU score: 0.10873134470594509
# 1819 Throw the dice. tira el dado | BLEU score: 0.03722145753922423
# 1820 They despise you. ellos te menosprecio | BLEU score: 0.03722145753922423
# 1821 Tom likes chocolate. a tom le gusta el chocolate | BLEU score: 0.16750095488258637
# 1822 They're small. están pequeño | BLEU score: 0
# 1823 It's dark. está oscuro | BLEU score: 0
# 1824 It's Tom's car. es el coche de tom | BLEU score: 0.03638962402527969
# 1825 Spring has come. la primavera llegó | BLEU score: 0.03722145753922423
# 1826 I'm better. mejor que mejor | BLEU score: 0
# 1827 How's this possible? cómo va en posible | BLEU score: 0
# 1828 We're moving. nos estoy moviendo | BLEU score: 0
# 1829 I gave up. yo adoro el teléfono | BLEU score: 0
# 1830 Tom was sleeping. tom estaba durmiendo | BLEU score: 0.03722145753922423
# 1831 He loved her. Él la amaba | BLEU score: 0.10873134470594509
# 1832 It's my turn. es mi turno | BLEU score: 0.03722145753922423
# 1833 Is something wrong? está algo mal | BLEU score: 0
# 1834 I'm not persuaded. no me convence | BLEU score: 0
# 1835 Tom shrugged. tom ronca | BLEU score: 0
# 1836 Let's try! hagámoslo | BLEU score: 0
# 1837 Just ask Tom. solo levántate a tom | BLEU score: 0.03701851938020757
# 1838 She's stark naked. ella está totalmente en canicas | BLEU score: 0.037374807627842434
# 1839 There's no water. no hay agua | BLEU score: 0.03722145753922423
# 1840 Tom ignored Mary. tom ignoraste a mary | BLEU score: 0.03701851938020757
# 1841 Stop babbling. deja de chismorrear | BLEU score: 0.03722145753922423
# 1842 Get some rest. descansa un poco de ello | BLEU score: 0.0456496931223525
# 1843 You're very patient. eres muy paciente | BLEU score: 0.03722145753922423
# 1844 I'm your sister. yo soy tu hermana | BLEU score: 0.04753271977233425
# 1845 I don't drink. yo no bebo | BLEU score: 0.03722145753922423
# 1846 It wasn't that. eso no era | BLEU score: 0.03722145753922423
# 1847 Tom walked. tom siguió caminando | BLEU score: 0
# 1848 Who escaped? quién escapó | BLEU score: 0
# 1849 Prices are high. los precios son altos | BLEU score: 0.03701851938020757
# 1850 I'm not rich. yo no soy rico | BLEU score: 0.04753271977233425
# 1851 That smells delicious. eso huele delicioso | BLEU score: 0.026670339752046985
# 1852 I went hiking. yo fui de excursión | BLEU score: 0.10202995073993343
# 1853 Tom is hysterical. tom está implicado | BLEU score: 0
# 1854 You may go. podéis ir | BLEU score: 0
# 1855 Play it again. tócalo otra vez | BLEU score: 0
# 1856 Continue without me. ¡qué me enseñó | BLEU score: 0
# 1857 Tom got nervous. tom se nervioso | BLEU score: 0.026670339752046985
# 1858 Everyone was drinking. todos estaba bebiendo | BLEU score: 0
# 1859 You must rest. tienes que correr | BLEU score: 0.03722145753922423
# 1860 They already know. ya son sensatos | BLEU score: 0
# 1861 Breathe normally. inspira profundamente | BLEU score: 0
# 1862 Is Tom lonely? tom está solo | BLEU score: 0
# 1863 Please calm down. por favor tranquilícese | BLEU score: 0
# 1864 Thanks for dinner. gracias por la cena | BLEU score: 0.10202995073993343
# 1865 We're very pleased. estamos muy confundida | BLEU score: 0.03722145753922423
# 1866 They hated Tom. ellos odiaban a tom | BLEU score: 0.04753271977233425
# 1867 Tom liked that. a tom le gustó | BLEU score: 0.07946100553299702
#
#
# Average BLEU score: 0.021493565071685806

# %% [markdown]
# ## CHRF

# %%
from nltk.translate.chrf_score import sentence_chrf

# %%
def calculate_chrf(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    return sentence_chrf([reference], candidate, min_len=2, max_len=6, beta=3.0)

test_eng_texts = []
for pair in test_pairs:
    eng_sentence = pair[0]
    test_eng_texts.append(eng_sentence)

test_spa_texts = []
for pair in test_pairs:
    spa_sentence = pair[1]
    test_spa_texts.append(spa_sentence)

print(len(test_eng_texts))

chrf_scores = []
for idx, (input_sentence, target_translation) in enumerate(zip(test_eng_texts, test_spa_texts)):
# for idx in range(30):
    # if idx >= 30:
    #     break

    translated = decode_sequence(input_sentence)
    translated = translated.replace("[start]", "").replace("[end]", "").strip() 

    chrf_score = calculate_chrf(target_translation, translated)
    chrf_scores.append(chrf_score)

    print(idx, input_sentence, translated, "| chrF score:", chrf_score)

average_chrf = np.mean(chrf_scores)
print("\n\nAverage chrF score:", average_chrf)
# Out:
# 1868
# 0 We're having dinner. estamos colgados en la cena | chrF score: 0.23028814154651345
# 1 Why not? por qué no interfieras | chrF score: 0.2093635853687812
# 2 Send him in. mándalo dentro | chrF score: 0.1621894607114041
# 3 I ate it. lo conozco | chrF score: 0.06629156563414278
# 4 I like climbing. me gusta la luz de las velas | chrF score: 0.20265479339994757
# 5 This doesn't fit. esto no cabe | chrF score: 0.102120026566992
# 6 Nobody's indispensable. nadie sabrá | chrF score: 0.06853018035548639
# 7 I don't eat. yo no como comer | chrF score: 0.12242529221082628
# 8 Ask me tomorrow. pregunta en mañana | chrF score: 0.17157868183882444
# 9 Raise your hands! levantá tus manos | chrF score: 0.23806587785868363
# 10 Here's your bag. aquí está tu cartera | chrF score: 0.27188411298948667
# 11 I see them. las veo | chrF score: 0.12793017662604753
# 12 We're Canadians. somos abogados | chrF score: 0.05424778311056875
# 13 They waited. se abrazaron | chrF score: 0.07253821054668874
# 14 Kiss Tom. besen a tomás | chrF score: 0.07891724115128373
# 15 Was I snoring? estaba equivocada | chrF score: 0.08853189082321447
# 16 You're too idealistic. eres demasiado generoso | chrF score: 0.2987394035592146
# 17 What's Tom hiding? qué está ocultando | chrF score: 0.42258380396203393
# 18 What'll we do? somos tengo | chrF score: 0.04674577490111477
# 19 Turn it off. apágalo | chrF score: 0.18442735176729042
# 20 Think about that. piénsatelo | chrF score: 0.01587301587301595
# 21 I played tennis. jugaba al tenis | chrF score: 0.4234385530560566
# 22 Speak more slowly. habla más despacio | chrF score: 0.34442114613896657
# 23 That's our secret. esa es nuestro secreto | chrF score: 0.4679246457942387
# 24 Try this candy. prueba esto | chrF score: 0.21258370351941064
# 25 I'm so happy. soy tan feliz | chrF score: 0.3519782827297096
# 26 You're unfair. eres injusto | chrF score: 0.2649189171294183
# 27 You were nice. fuisteis arrogantes | chrF score: 0.038426081126382905
# 28 Nobody is speaking. nadie está hablando | chrF score: 0.3957494745158764
# 29 It's a dictionary. es un turista | chrF score: 0.055986597049399046
# 30 Who invented karaoke? quién va a el karaoke | chrF score: 0.2411994547457375
# 31 Is it yours? es suyo | chrF score: 0.009852216748768553
# 32 It's 8:30. es usted | chrF score: 0.009803921568627529
# 33 Somebody poisoned Tom. alguien a tom | chrF score: 0.11597730314675529
# 34 Be confident. sé confiado | chrF score: 0.024137478682933287
# 35 Tom's unstoppable. tom está viniendo | chrF score: 0.04540648496240608
# 36 Does truth matter? la verdad importa | chrF score: 0.3196369020318927
# 37 Things eventually changed. las cosas cambiaron en las cosas en las cosas en las cosas cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron cambiaron | chrF score: 0.23374417827335883
# 38 They're enjoying themselves. ellas se divierten | chrF score: 0.06419788751467008
# 39 Tom wanted revenge. tom quería con venganza | chrF score: 0.3554486313644131
# 40 He resigned. Él renunció | chrF score: 0.370717955701683
# 41 I'm in Perth. estoy en línea | chrF score: 0.14090448582319895
# 42 Have another cup. sírvase otra copa | chrF score: 0.3284864595540166
# 43 You look awful. pareces aburrido | chrF score: 0.036664729254604594
# 44 It was exhilarating. fue emocionante | chrF score: 0.07461285834294142
# 45 That's Tom's apartment. esa es el apartamento de tom | chrF score: 0.4341510343532966
# 46 Who invented that? quién piensa eso | chrF score: 0.07697569593875289
# 47 I got divorced. me pidieron divorciada | chrF score: 0.20811887638588034
# 48 We're not family. no somos familia | chrF score: 0.4383427177405885
# 49 I'm not Tom. no soy tom | chrF score: 0.07735566662379043
# 50 Flip a coin. los una zorra | chrF score: 0.024940451169959427
# 51 I'd be honored. yo sé clemente | chrF score: 0.007117437722420006
# 52 They're not soldiers. no son criminales | chrF score: 0.05170427151008143
# 53 I like milk. me gusta la leche | chrF score: 0.4383427177405885
# 54 Tom embraced Mary. tom abandonó a mary | chrF score: 0.09006312656300233
# 55 It's nearly 2:30. van a ser las dos y media | chrF score: 0.32987624322055537
# 56 Go meet Tom. ve a tom | chrF score: 0.029556650246305504
# 57 You're sick! estáis mal | chrF score: 0.026135991839719847
# 58 I'm behind you soy tu usted | chrF score: 0.01587301587301595
# 59 You survived. sobreviviste | chrF score: 0.3014439164907953
# 60 I've heard rumors. oí por favor | chrF score: 0.025641025641025723
# 61 I'm impressed. estoy impresionada | chrF score: 0.46530353521725454
# 62 I'm confused now. ahora confundida | chrF score: 0.25143596483395675
# 63 Don't disturb me. no me molestes | chrF score: 0.38358683446071334
# 64 It hurts. duele | chrF score: 0.08002598500928108
# 65 Stop harassing Tom. deja de tom | chrF score: 0.08192767482109979
# 66 That's correct. eso es cierto | chrF score: 0.02884615384615393
# 67 I missed you. te extrañé | chrF score: 0.008583690987124542
# 68 Breathe normally. inspira profundamente | chrF score: 0.08044746692121972
# 69 Women are beautiful. las mujeres son guapa | chrF score: 0.3380594252483554
# 70 Can I begin? puedo ir | chrF score: 0.05148221343873523
# 71 Something must've happened. algo odia algo | chrF score: 0.027832512315271007
# 72 I agreed. yo accedí | chrF score: 0.011834319526627297
# 73 Should I go? deberíamos seguir | chrF score: 0.16025359520452861
# 74 They've been arrested. le han tendido una emboscada | chrF score: 0.07355060034305323
# 75 He became famous. Él se puso como | chrF score: 0.06672649201524586
# 76 Flip a coin. los una zorra | chrF score: 0.027929704456102555
# 77 He teaches English. Él habla inglés | chrF score: 0.12609539681851617
# 78 Go get it. ve a por ello | chrF score: 0.28928927007202676
# 79 I didn't sing. yo no canto | chrF score: 0.22099323224457196
# 80 Who's that man? quién es aquel hombre | chrF score: 0.2272203536926603
# 81 He is intelligent. Él es inteligente | chrF score: 0.5045605951989421
# 82 Try again. prueba otra vez | chrF score: 0.2181690649726992
# 83 He went shopping. Él salió a compras | chrF score: 0.15611064518292644
# 84 I am exhausted. estoy reventado | chrF score: 0.1168038075251974
# 85 You know everything. usted sabe todo | chrF score: 0.12230495511355474
# 86 Just take one. cojan solo una | chrF score: 0.1979136387699773
# 87 I speak fast. yo hablo rápido | chrF score: 0.34845654881910565
# 88 They're already here. ellas ya están aquí | chrF score: 0.3433047648324129
# 89 I'm not sad. no estoy triste | chrF score: 0.41224271568547016
# 90 Tie your shoelaces. Átate los cordones | chrF score: 0.4066608257843953
# 91 You shouldn't go. por preguntarme ahí | chrF score: 0.0262503883193539
# 92 It's dirty work. es trabajo trabajar | chrF score: 0.22241332580463014
# 93 Loosen it. suéltala | chrF score: 0.02139037433155088
# 94 Tom's adopted. tom es soy | chrF score: 0.05331404924768625
# 95 I'm so stupid. es muy tonto | chrF score: 0.016460905349794316
# 96 I hate riddles. odio el odio a los odio | chrF score: 0.04518379239568837
# 97 People like me. caigo bien a la gente | chrF score: 0.23135240043189312
# 98 Cook for me. cocina para mí | chrF score: 0.041884816753926794
# 99 Come aboard. sal a bordo | chrF score: 0.15639354586548668
# 100 You're turning red. tú te estás poniendo rojo | chrF score: 0.27716058089873247
# 101 They all knew. lo supieron | chrF score: 0.026022588522588586
# 102 Let's finish this. comamos | chrF score: 0.025362318840579774
# 103 Everything went black. todo anduvo | chrF score: 0.03732193732193738
# 104 He ran. Él corrió | chrF score: 0.29431490039422853
# 105 I despise you. yo te menosprecio | chrF score: 0.21305387110542306
# 106 Be realistic! sé exhaustivo | chrF score: 0.00917431192660558
# 107 Tom looks tense. tom parece estar impaciente | chrF score: 0.271687513669562
# 108 Nobody likes Tom. nadie le gusta a tom | chrF score: 0.07910853763861138
# 109 That's serious. eso es en serio | chrF score: 0.06896002505629592
# 110 I'm hit! soy la fecha | chrF score: 0.06139097143770045
# 111 God bless you! dios eres la usted | chrF score: 0.05145797598627795
# 112 Help! ¡ayuda | chrF score: 1.0000000000000001e-16
# 113 We're friends. somos amigas | chrF score: 0.249927618592656
# 114 Where's the bread? dónde está el en dónde está el dónde está el en dónde está el dónde está las dónde está dónde | chrF score: 0.2602601198136826
# 115 I'll walk. voy a andar | chrF score: 0.02127659574468093
# 116 Check again. compruébalo otra vez | chrF score: 0.02338461538461544
# 117 There's no hurry. hace falta favor | chrF score: 0.018957345971564062
# 118 I'm from Kyoto. soy de los estados unidos | chrF score: 0.08481872358019152
# 119 Tom betrayed me. tom me traicionó | chrF score: 0.4383427177405885
# 120 He denied everything. Él lo negó todo | chrF score: 0.22861661661692176
# 121 I couldn't sleep. no pude dormir | chrF score: 0.38358683446071334
# 122 They're good. están bien | chrF score: 0.030456852791878257
# 123 Who wants it? quién lo quiere | chrF score: 0.3958579138425403
# 124 She is French. es guapa | chrF score: 0.00833333333333341
# 125 Are you Japanese? usted es japonés | chrF score: 0.25530872636135793
# 126 You're unfair. eres injusto | chrF score: 0.26176334821445985
# 127 Keep on smiling. continuad sonriendo de sonriendo | chrF score: 0.31001845972292746
# 128 It's already late. ya se nos hizo tarde | chrF score: 0.11318082620302952
# 129 I gave up. yo adoro el teléfono | chrF score: 1.0000000000000001e-16
# 130 You're very skeptical. eres muy escéptica | chrF score: 0.4435156569113018
# 131 What's today's menu? qué menú es en serio | chrF score: 0.07147061478739736
# 132 Tom wasn't kidding. tom no estaba jodiendo | chrF score: 0.2760222348996074
# 133 Make an offer. he estado guapa | chrF score: 0.026718171575728377
# 134 That's me. eso yo | chrF score: 0.0786618885679112
# 135 Tom started whining. tom empezó a comer | chrF score: 0.06948305215288661
# 136 Keep the secret. seguí secreto | chrF score: 0.16789303830436123
# 137 You're babbling. tú estás murmurando | chrF score: 0.15037016465265174
# 138 You're ignoring me. estás me odia | chrF score: 0.07949349022956911
# 139 Take it. hagámoslo | chrF score: 0.011764705882353019
# 140 They're not coming. no son idiotas | chrF score: 0.02675585284280945
# 141 It's a secret. es secreto | chrF score: 1.0000000000000001e-16
# 142 Are you bald? estás tú calvo | chrF score: 0.11990422723299103
# 143 Tom bowed. tom se inclinó | chrF score: 0.38358683446071334
# 144 Tom continued writing. tom siguió escribiendo | chrF score: 0.2997147059339774
# 145 Let's celebrate. ¡Órale | chrF score: 0.009852216748768553
# 146 Let's chat. vamos a charlar | chrF score: 0.10216482885966457
# 147 He gave up. Él se rindieron | chrF score: 0.011494252873563295
# 148 What gives? qué pasa | chrF score: 0.011299435028248666
# 149 Tom came yesterday. tom se ayer | chrF score: 0.03766307430516171
# 150 I'm staying here. soy aquí | chrF score: 0.058236141882562174
# 151 I like puzzles. me gusta la luz de las velas | chrF score: 0.09907015696864448
# 152 Are they cops? están satisfechos | chrF score: 0.01960784313725498
# 153 Hurry up, Tom. ¡apúrensen muchachas | chrF score: 0.03596899224806208
# 154 Mary looks beautiful. mary se ve hermosa | chrF score: 0.025470026127788703
# 155 You're home early. estás en la temprano | chrF score: 0.019736842105263237
# 156 Is it good? es tú | chrF score: 0.009950248756218983
# 157 I'll be alone. voy a estar solo | chrF score: 0.11819548872180455
# 158 How was Boston? ¡qué fue boston | chrF score: 0.08961564767751075
# 159 Tom refused. tom en banda en banda | chrF score: 0.03902439024390252
# 160 My name's Tom. me llamo tom | chrF score: 0.008547008547008624
# 161 See above. véase arriba | chrF score: 0.18106561784181446
# 162 I'll remember that. le recuerda eso | chrF score: 0.05566843634615811
# 163 She admired him. ella lo perdonó | chrF score: 0.08490242832031843
# 164 Read after me. lean después de mí | chrF score: 0.36449237542426494
# 165 You're too modest. sos demasiado generoso | chrF score: 0.29262989406736306
# 166 Stay right there. mantente en allí | chrF score: 0.018957345971564062
# 167 You want this? eres este | chrF score: 0.19311488939423288
# 168 I didn't stop. yo no yo | chrF score: 0.02757822049709427
# 169 They all know. todos los conocen | chrF score: 0.19547198034612223
# 170 They already know. ya son sensatos | chrF score: 0.04426203122485119
# 171 Watch us. déjanos | chrF score: 0.060899886624304636
# 172 I watched you. yo observé | chrF score: 1.0000000000000001e-16
# 173 Tom likes games. a tom le gusta la juegos | chrF score: 0.3011742226143888
# 174 Stop it. déjalo | chrF score: 0.01136363636363644
# 175 Need anything else? cualquier cosa se cualquier cosa | chrF score: 0.027777777777777863
# 176 You must try. tienes que irte | chrF score: 0.10159280144435692
# 177 You're very clever. eres muy listo | chrF score: 0.04296726241283771
# 178 Tom escaped injury. tom evitó males mayores | chrF score: 0.007380073800738085
# 179 I'll change. voy a cambiar | chrF score: 0.170703474372205
# 180 He's really quick. Él es realmente rápido | chrF score: 0.1047777895095185
# 181 Tom isn't dumb. tom no es estúpido | chrF score: 0.4622153469253476
# 182 Tom was adopted. tom fue despedido | chrF score: 0.09225083625450306
# 183 Think about it. piénsatelo | chrF score: 0.02329379798812419
# 184 That's the attitude. esa es la emergencia | chrF score: 0.1351259175607002
# 185 I ate caviar. yo comió quedito | chrF score: 0.009478672985782071
# 186 Stand by. un momento | chrF score: 0.010152284263959466
# 187 I was disillusioned. yo estaba desilusionado | chrF score: 0.5364412196179412
# 188 Just say yes. di que sí | chrF score: 0.19405584774887036
# 189 I'm fixing something. soy algo | chrF score: 0.06445307092774824
# 190 Unfasten the pin. ¡qué los estados unidos | chrF score: 0.02481074481074487
# 191 Close the gate. cierra las persianas | chrF score: 0.1780093702344558
# 192 Tom is energetic. tom está implicado | chrF score: 0.06814888010540189
# 193 I got hit. me pidieron identificarme | chrF score: 0.050788736547250544
# 194 They're identical. están rotos | chrF score: 0.017777777777777854
# 195 Tom was scared. tom fue asustado | chrF score: 0.05164786551647872
# 196 That's obscene. ¡eso es obsceno | chrF score: 0.3817480404492538
# 197 Don't touch this! no toques esto | chrF score: 0.36765150932951557
# 198 This is disgusting. esto es repugnante | chrF score: 0.4841349520272651
# 199 There's no mistake. no hay ningún error | chrF score: 0.1570058279245471
# 200 Why is that? por qué pasa eso | chrF score: 0.11866060598556978
# 201 Tom bit me. tom me mordió | chrF score: 0.3519782827297096
# 202 I love butterflies. me encantan las bodas | chrF score: 0.30168458294182376
# 203 You weren't funny. no fuisteis graciosos | chrF score: 0.3547232751145795
# 204 That explains everything. eso explica todo | chrF score: 0.4383427177405885
# 205 No way! ¡de eso nada | chrF score: 0.018518518518518594
# 206 Are you vegetarian? eres tú eres eres eres eres | chrF score: 0.029582584715664627
# 207 Tom's great. tom es genial | chrF score: 0.0588094737684902
# 208 It's Sunday today. es tu día de hoy | chrF score: 0.026431718061674096
# 209 Go on in. entra | chrF score: 0.05182200268642495
# 210 This is exhilarating. esto es incoherente | chrF score: 0.10416543138849998
# 211 You are important. ustedes son importantes | chrF score: 0.3165344229596756
# 212 It was perfect. fue perfecto | chrF score: 0.249927618592656
# 213 Pull the trigger. bate los dientes | chrF score: 0.03361344537815135
# 214 I needed that. yo necesité eso | chrF score: 0.23374681622607807
# 215 He likes money. le gusta dinero | chrF score: 0.2489615315035795
# 216 Are they brothers? son hermanos | chrF score: 0.3366691874778663
# 217 I'm already late. ya estoy atrasado | chrF score: 0.018867924528301966
# 218 She stood up. ella se quedó | chrF score: 0.0975806068797947
# 219 Tom needs help. tom necesita ayuda | chrF score: 0.4841349520272651
# 220 It's still closed. aún está cerrados | chrF score: 0.3010204645793354
# 221 I'm home, Tom. soy en casa | chrF score: 0.2134945808206245
# 222 Tom is wicked. tom está implicado | chrF score: 0.05981554677206856
# 223 They have wine. ellas tienen vino | chrF score: 0.3181692739224595
# 224 Is Tom crazy? tom está loco | chrF score: 0.3366691874778663
# 225 Shame on you! ¡avergüénzate | chrF score: 0.11397021761359834
# 226 I'm having fun. soy calvo | chrF score: 0.007220216606498272
# 227 We surrendered. lo procuramos | chrF score: 0.027964008468595692
# 228 Tom was horrified. tom fue artero | chrF score: 0.03367626806772293
# 229 I'm absolutely sure! soy absolutamente segura | chrF score: 0.5080990361173388
# 230 Only Tom knows. sólo sabe tom | chrF score: 0.07555890507029973
# 231 Tom reluctantly left. tom se fue | chrF score: 0.15307202293535932
# 232 Where's Tom's office? dónde está la oficina de tom | chrF score: 0.49561655182292164
# 233 Tom drove fast. tom condujo rápido | chrF score: 0.4841349520272651
# 234 I'm not sick. no estoy enferma | chrF score: 0.4383427177405885
# 235 You are dreaming. estás muy soñando | chrF score: 0.24056891239957606
# 236 We've altered course. hemos este tornillo | chrF score: 0.046963485171681765
# 237 What's good? qué está bien | chrF score: 0.3366691874778663
# 238 Don't smoke here. no fume aquí | chrF score: 0.15472343720520537
# 239 Write an answer. escriba una respuesta | chrF score: 0.415699985965163
# 240 I love golf. me encantan las bodas | chrF score: 0.20556815648119992
# 241 That's theirs. eso es suya | chrF score: 1.0000000000000001e-16
# 242 Everyone cheered. todos vitorearon | chrF score: 0.11074842549560251
# 243 You're my hero. eres mi héroe | chrF score: 0.26176334821445985
# 244 Are you satisfied? estáis satisfechos | chrF score: 0.3430428560423226
# 245 I'm twelve. soy imparcial | chrF score: 0.010000000000000077
# 246 We're watching. miramos | chrF score: 0.1029644268774704
# 247 Are you bored? te aburres | chrF score: 0.08637190048735563
# 248 Do you smoke? entendiste | chrF score: 0.058951911523087916
# 249 They will come. van a sal | chrF score: 1.0000000000000001e-16
# 250 Leave him alone. ¡déjame irse | chrF score: 0.00921658986175123
# 251 You're so thin. eres tan delgado | chrF score: 0.03679653679653686
# 252 That's evident. ¡eso es evidente | chrF score: 0.00990099009900998
# 253 You're not stupid. no sos estúpido | chrF score: 0.2181690649726992
# 254 Alcoholism is incurable. las sentamos tienen calor | chrF score: 0.04057971014492762
# 255 Tom helps us. tom ayuda a nosotras | chrF score: 0.13040608230236045
# 256 Appearances are deceiving. las cerezas son rusos | chrF score: 0.01273885350318479
# 257 It's lunch time. es el momento | chrF score: 0.022140221402214104
# 258 I miss it. lo vi | chrF score: 1.0000000000000001e-16
# 259 Look at us. mira allí | chrF score: 1.0000000000000001e-16
# 260 She adores cats. ella adora a los gatos | chrF score: 0.42160408684039485
# 261 We're defenseless. estamos indefensos | chrF score: 0.1501441669326134
# 262 Isn't that terrific? a que es tremendo | chrF score: 0.03273031654110941
# 263 Answer the question. responde a la pregunta | chrF score: 0.4060004535252787
# 264 Knock before entering. las vacas dan leche | chrF score: 0.03049242424242431
# 265 That's too personal. esa es una personal | chrF score: 0.17049575922743399
# 266 It's vibrating. es usted | chrF score: 0.009009009009009087
# 267 They are exhausted. ellos están reventado | chrF score: 0.09033618233618237
# 268 I can't sleep. no puedo dormir | chrF score: 0.41224271568547016
# 269 That's simple. eso es simple | chrF score: 0.2299389404884761
# 270 Tom is patient. tom está paciente | chrF score: 0.28514199111672056
# 271 They're coming back. ellas están regresando | chrF score: 0.2341563019149918
# 272 Isn't that terrific? a que es tremendo | chrF score: 0.03273031654110941
# 273 It looks fascinating. se ve fascinante | chrF score: 0.32427385727474445
# 274 You are deranged. eres guapa | chrF score: 1.0000000000000001e-16
# 275 Tom left. tom se fue | chrF score: 0.23399993461595742
# 276 Tom is right-handed. tom es independiente | chrF score: 0.10534994773325705
# 277 Here, drink this. toma bébete esto | chrF score: 0.06873497829841743
# 278 Sign this. firma esto | chrF score: 0.09414641784537178
# 279 There's our bus. ¡ahí viene nuestro bus | chrF score: 0.2824204298208196
# 280 Just take one. cojan solo una | chrF score: 0.14714867919845692
# 281 I'm your lawyer. soy tu abogado | chrF score: 0.38358683446071334
# 282 My stomach's full. tengo la panza llena | chrF score: 0.0941507440633778
# 283 It's a gimmick. es un truco | chrF score: 0.02836074872376637
# 284 Show me. muéstrame cómo | chrF score: 0.24744206026392818
# 285 Hold it! déjalo | chrF score: 1.0000000000000001e-16
# 286 You should exercise. deberías ir de hacer | chrF score: 0.1947106092991288
# 287 Look it up. búscalo | chrF score: 0.02051282051282059
# 288 I'm begging you. soy muy | chrF score: 0.007518796992481281
# 289 Help yourself, please. ayuda por favor | chrF score: 0.17102196659368002
# 290 Do you promise? entendiste | chrF score: 0.04674577490111477
# 291 Tom resigned. tom renunció | chrF score: 0.23772368863642196
# 292 What are they? qué son | chrF score: 0.14500643912393466
# 293 Tom is disagreeable. tom está implicado | chrF score: 0.063292083525083
# 294 You shouldn't eavesdrop. tú no deberías escuchar a escondidas | chrF score: 0.36882910193255014
# 295 She trusts him. ella lo perdonó | chrF score: 0.032864820173625534
# 296 I'm fit. soy este | chrF score: 0.03646098929117804
# 297 Speak quietly. habla quedito | chrF score: 0.10079992280600188
# 298 It's almost time. ya casi son momento | chrF score: 0.09934695928479452
# 299 It's a problem. ese es un problema | chrF score: 0.37812307448463056
# 300 I have dandruff. yo tengo órdenes | chrF score: 0.06828639364404751
# 301 Tom will go. tom va a ir | chrF score: 0.023668639053254517
# 302 They want this. quiero este | chrF score: 0.10310504048586489
# 303 I'm your friend. soy tu amigo | chrF score: 0.26314837547974845
# 304 Everybody likes her. todos quieren | chrF score: 0.08102120800243781
# 305 No one shouted. nadie murió | chrF score: 0.06964709868886329
# 306 Save Tom. ahórrate tomás | chrF score: 0.009950248756218982
# 307 He seems sick. Él se ve enfermo | chrF score: 0.21774041366505367
# 308 You made it. lo has | chrF score: 0.03273031654110941
# 309 He's a tycoon. Él es ninja | chrF score: 1.0000000000000001e-16
# 310 We'll follow Tom. le daré a tom | chrF score: 0.015325670498084368
# 311 It smells good! va bien | chrF score: 0.009852216748768553
# 312 Don't fight. no lo cambia | chrF score: 1.0000000000000001e-16
# 313 I'm happy, Tom. soy feliz | chrF score: 0.2426170434191266
# 314 Smoking stinks. fumar fumar | chrF score: 0.06665859439784548
# 315 That dog jumped. esa perro brincó | chrF score: 0.09629660466496894
# 316 Where's the toilet? dónde está el servicio | chrF score: 0.2776833890746934
# 317 It's true. ¡eso es verdad | chrF score: 0.22861661661692176
# 318 I'm your father. soy tu padre | chrF score: 0.33830380317050757
# 319 I'm very tired. soy muy cansado | chrF score: 0.3807302977268756
# 320 I was dismissed. yo fue despedido | chrF score: 0.2837915028244903
# 321 Don't be evil. no seas mal | chrF score: 0.2645482194724756
# 322 I use this. uso esto | chrF score: 0.09876968604198498
# 323 I'm grieving. soy imparcial | chrF score: 0.018348623853211083
# 324 I'll do that. voy a eso | chrF score: 0.03457491796068886
# 325 I'm always happy. soy feliz | chrF score: 0.15854781752433098
# 326 Tom caught Mary. tom lo dijo a mary | chrF score: 0.03398201385817491
# 327 You're getting closer. tú estás poniendo más calor | chrF score: 0.12021770127026792
# 328 Follow his example. siga su ejemplo | chrF score: 0.27072135849097245
# 329 Don't be absurd. no seas absurdo | chrF score: 0.36596261455834195
# 330 You'll understand someday. vas a entender | chrF score: 0.1891854586269036
# 331 Where's the entrance? dónde queda el ingreso | chrF score: 0.21438594069499978
# 332 Don't come again. no hagas otra vez | chrF score: 0.008403361344537893
# 333 I'm not yelling. no voy a ser el sordo | chrF score: 0.015503875968992322
# 334 It's very sad. es muy triste | chrF score: 0.3519782827297096
# 335 Send him in. mándalo dentro | chrF score: 0.15617344282261808
# 336 You're disorganized. eres desorganizado | chrF score: 0.22989573137113
# 337 I'm already ready. ya estoy lista | chrF score: 0.35307752728218633
# 338 It's too expensive! es demasiado caro | chrF score: 0.44531703562217817
# 339 You were lucky. tuviste suerte | chrF score: 0.0316926770708284
# 340 Make way, please. por allí | chrF score: 0.02925792742726388
# 341 Got it? lo pillas | chrF score: 1.0000000000000001e-16
# 342 You may swim. podéis ir | chrF score: 1.0000000000000001e-16
# 343 Do you understand? entendiste | chrF score: 0.13077951239322347
# 344 We'll be neighbors. seremos asesinados | chrF score: 0.14823338336052788
# 345 I'm running late. voy con retraso | chrF score: 0.41224271568547016
# 346 We're like family. somos como de familia | chrF score: 0.321672385012631
# 347 I must refuse. yo debo esconderme | chrF score: 0.09186491408036253
# 348 They seem fine. ellos se pusieron guapa | chrF score: 0.007380073800738085
# 349 You're in love. tú estás amor | chrF score: 0.10122550491402955
# 350 I'm horrified. soy imparcial | chrF score: 0.015209125475285246
# 351 Let's stay married. sigamos casados | chrF score: 0.26402733146825347
# 352 I love reading. adoro la leyendo | chrF score: 0.051157305027274134
# 353 Draw a circle. los una zorra | chrF score: 0.015810276679841972
# 354 I will work. yo miré a trabajar | chrF score: 0.28244970132841984
# 355 Don't believe him. le creas | chrF score: 1.0000000000000001e-16
# 356 It doesn't matter. no importa | chrF score: 0.2906973142101422
# 357 What's up, dude? qué hay ha fastidiado | chrF score: 0.02479338842975214
# 358 I am disappointed. estoy reventado | chrF score: 0.08169617898625317
# 359 Check your order. comprueba tu buzón | chrF score: 0.007490636704119928
# 360 I talked. esperé | chrF score: 1.0000000000000001e-16
# 361 What's their purpose? cuál es su congresista | chrF score: 0.1749010601061089
# 362 I'm in danger. soy en peligro | chrF score: 0.3529923732888077
# 363 We're both fine. los dos estamos en punto | chrF score: 0.35135246235246237
# 364 Everyone dies eventually. todo el mundo se quedó finalmente | chrF score: 0.35195258188104844
# 365 They're insane. están molidos de la cabeza | chrF score: 0.04065040650406512
# 366 Listen to this! escucha a esto | chrF score: 0.23327250191889498
# 367 Stop blaming yourself. deja de torturarte | chrF score: 0.10880498464709021
# 368 The two laughed. ambos rieron | chrF score: 0.1386495866962751
# 369 Stop complaining. deja de quejarte | chrF score: 0.313764935167276
# 370 I'm nervous. estoy nervioso | chrF score: 0.41224271568547016
# 371 I'm kidding. estoy jodiendo | chrF score: 0.41224271568547016
# 372 He helps her. Él ayuda | chrF score: 0.12020903300880939
# 373 I want one! quiero uno | chrF score: 0.2645482194724756
# 374 It's improved. es encantador | chrF score: 0.05326945329787457
# 375 Tom is miserly. tom está implicado | chrF score: 0.10356557870218437
# 376 I wouldn't care. me mal mal | chrF score: 0.00829875518672207
# 377 Wait, don't shoot! ¡espera no dispares | chrF score: 0.2755539254008825
# 378 I sat down. me senté | chrF score: 0.10843642843642845
# 379 Take it upstairs. llévalo arriba | chrF score: 0.19727585707130807
# 380 He turned Christian. Él cumplió 13 años | chrF score: 0.011527377521613914
# 381 Tomorrow is Christmas. mañana será navidad | chrF score: 0.20289726673433311
# 382 OK, listen up. ha empezado | chrF score: 1.0000000000000001e-16
# 383 I'm begging you. soy muy | chrF score: 0.007518796992481281
# 384 They demoted you. te degradaron | chrF score: 0.05783760312635698
# 385 No one answered. nadie respondió | chrF score: 0.4383427177405885
# 386 Speak slower, please. habla por favor | chrF score: 0.1698031451331948
# 387 I'm already busy. ya estoy hasta las manos | chrF score: 0.1495661958077497
# 388 I threw up. yo odio el teléfono | chrF score: 1.0000000000000001e-16
# 389 I can fly. yo puedo explicar | chrF score: 0.0679544959212903
# 390 So long. tan tan tan tan | chrF score: 0.019138755980861323
# 391 Where's the shovel? dónde está el baño | chrF score: 0.2006039631025509
# 392 Once more, please. por favor retroceda | chrF score: 0.1856635386854592
# 393 Bless you. te encuentras | chrF score: 0.012195121951219589
# 394 Tom agreed. tom convino aquiescente | chrF score: 0.02068965517241387
# 395 These are great. estos son genial | chrF score: 0.41372722620427804
# 396 Don't play dead. no hagas el trabajo | chrF score: 0.15366164227678314
# 397 Will Tom die? va a tom | chrF score: 0.01809954751131229
# 398 They are here. ellas ellas están aquí | chrF score: 0.26314837547974845
# 399 They've come back. volvamos | chrF score: 1.0000000000000001e-16
# 400 Is something wrong? está algo mal | chrF score: 0.06432748538011704
# 401 Are they friends? son estadounidenses | chrF score: 0.054461538461538526
# 402 Tom moved. tom se mudó | chrF score: 0.10231620906199226
# 403 Tom isn't religious. tom no es creyente | chrF score: 0.1340705329143042
# 404 Who called me? quién llamó por mí | chrF score: 0.1392121663928862
# 405 It's Saturday today. es sábado | chrF score: 0.25375150140226044
# 406 They mean business. ellos son bienintencionados | chrF score: 0.07364595245053791
# 407 Nobody's perfect. nadie perfecto | chrF score: 0.25826385708497485
# 408 Tom felt sad. tom se sintió triste | chrF score: 0.5043324742524915
# 409 He knows everything. sabe todo | chrF score: 0.2426170434191266
# 410 Today is Wednesday. día de miércoles | chrF score: 0.26144278632030143
# 411 Tom almost drowned. tom casi en las seis | chrF score: 0.15176492299525457
# 412 Thanks for understanding. gracias por comprenderlo | chrF score: 0.3552053883074474
# 413 They're under arrest. ellas están detenidos | chrF score: 0.12501916338245142
# 414 Tom is singing. tom está cantando | chrF score: 0.13995727180412812
# 415 She's rather clueless. ella es bastante guapa | chrF score: 0.30922474022232993
# 416 You cheated. hiciste trampa | chrF score: 0.2489615315035795
# 417 I hate rules. odio las reglas | chrF score: 0.41224271568547016
# 418 It's finally over. se acabó | chrF score: 0.15918059109955818
# 419 That's my car. ese es mi coche | chrF score: 0.14714867919845692
# 420 I am American. soy americano | chrF score: 0.0073529411764706645
# 421 You're a nobody. eres un nadie | chrF score: 0.21608371352139324
# 422 I love trips. me encantan las bodas | chrF score: 0.2516547863909134
# 423 Tom started whimpering. tom empezó a la historia | chrF score: 0.047445935868754736
# 424 Isn't that true? es verdad | chrF score: 0.22305364524517107
# 425 He walks fast. Él anda rápido | chrF score: 0.1982515282379265
# 426 Wait here. esperad aquí | chrF score: 0.16096359148594389
# 427 I was captured. yo era veloz | chrF score: 0.008888888888888965
# 428 Look out! mira hacia adelante | chrF score: 0.01069518716577548
# 429 I'm very happy. soy muy feliz | chrF score: 0.3519782827297096
# 430 Close your book. cierra tu libro | chrF score: 0.41224271568547016
# 431 You'll go far. llegaréis lejos | chrF score: 0.18304153065541828
# 432 I already know. ya puedo | chrF score: 1.0000000000000001e-16
# 433 He's a historian. Él es ninja | chrF score: 1.0000000000000001e-16
# 434 Tom's not breathing. tom no está respirando | chrF score: 0.24333731324313784
# 435 Don't shout. no interfieras | chrF score: 0.010416666666666744
# 436 Nobody bought it. nadie lo engañes | chrF score: 0.09706395396693582
# 437 Cross the street. cruza el las bodas | chrF score: 0.07118388857519296
# 438 This is easy. esto es fácil | chrF score: 0.11057129930655289
# 439 They're in. ellas están dentro | chrF score: 0.048192771084337435
# 440 I do remember. me lo acuerdo | chrF score: 0.12095774742643535
# 441 Someone screamed. alguien gritó | chrF score: 0.38358683446071334
# 442 I'm housesitting. soy guardés | chrF score: 0.18427951070382956
# 443 She trusted you. ella te confiaba en usted | chrF score: 0.3051833648849047
# 444 Are you blind? eres guapa | chrF score: 1.0000000000000001e-16
# 445 Tom is different. tom es diferente | chrF score: 0.4383427177405885
# 446 Go on inside. entra | chrF score: 0.0645067000404407
# 447 Water is important. agua es importante | chrF score: 0.489108112686259
# 448 They ate marshmallows. ellas comieron bombones | chrF score: 0.4745319003908725
# 449 I'm dancing. estoy bailando | chrF score: 0.41224271568547016
# 450 How's school? cómo te va en el colegio | chrF score: 0.0447293447293448
# 451 See you. hasta la ver | chrF score: 0.04291921610357371
# 452 Has someone died? ha venido alguien | chrF score: 0.2081227600950321
# 453 Who's first? le toca primero | chrF score: 0.15545815100288093
# 454 She smells bad. ella huele mal | chrF score: 0.38358683446071334
# 455 It's hot here. hace calor aquí | chrF score: 0.41224271568547016
# 456 Check your inbox. comprueba tu buzón | chrF score: 0.017878437385121685
# 457 Wake Tom up. despiértate tom | chrF score: 0.08591026946751665
# 458 He's a lawyer. Él es abogado | chrF score: 0.4030036147982363
# 459 The noise continued. la seguí continuaba | chrF score: 0.16443120579470158
# 460 Who's here? quién está aquí | chrF score: 0.3958579138425403
# 461 She fell asleep. ella se durmió | chrF score: 0.38358683446071334
# 462 He enjoyed cycling. Él se puso en se le engañes | chrF score: 0.021052631578947448
# 463 Come over. veníos | chrF score: 0.010309278350515542
# 464 Read the article. lean el cuchillo | chrF score: 0.025210084033613533
# 465 There's someone outside. hay alguien afuera | chrF score: 0.4841349520272651
# 466 Thanks in advance. te agradezco de antemano | chrF score: 0.015209125475285249
# 467 You're great. eres genial | chrF score: 0.03456959706959713
# 468 Atlantis is real. fue real | chrF score: 0.046133278438892776
# 469 Nobody was tortured. nadie fue torturado | chrF score: 0.2755539254008825
# 470 I'll miss Tom. voy a tom | chrF score: 0.007490636704119927
# 471 It's sweltering. es usted | chrF score: 0.010256410256410334
# 472 Is Tom guilty? es fuera tom | chrF score: 0.016460905349794316
# 473 Please listen. por favor escucha | chrF score: 0.41987009865175295
# 474 He trusted you. le confiaba en usted | chrF score: 0.10334477759145215
# 475 Keep it. ¡continúa | chrF score: 1.0000000000000001e-16
# 476 Let's ask him. mantengámoslo | chrF score: 0.06903182806320476
# 477 I miss it. lo vi | chrF score: 1.0000000000000001e-16
# 478 This bucket leaks. este balde pierde | chrF score: 0.012500000000000077
# 479 I'm from Tokyo. soy de los estados unidos | chrF score: 0.08481872358019152
# 480 Tom left Mary. tom se fue a mary | chrF score: 0.03549010140028978
# 481 It's exhilarating. es usted | chrF score: 0.017316017316017392
# 482 I was insulted. yo estaba deprimida | chrF score: 0.03629550095791497
# 483 Come right in. sal | chrF score: 1.0000000000000001e-16
# 484 I eat meat. yo como pan | chrF score: 0.09780122633213957
# 485 I'm up. estoy reventado | chrF score: 0.15071689467755492
# 486 Business is slow. la empresa es más despacio | chrF score: 0.019633947029472625
# 487 They stopped singing. ellos pararon de cantar | chrF score: 0.3584105514455715
# 488 Say cheese. di patata | chrF score: 0.00896860986547093
# 489 We've got it. lo hemos | chrF score: 0.06381942381942385
# 490 Isn't it stunning? no es usted aspecto | chrF score: 0.035342902711323836
# 491 Tom ate quickly. tom comió rápido | chrF score: 0.32906518000289464
# 492 Let him in. déjenlo entrar | chrF score: 0.24561716725410898
# 493 What's the problem? cuál es el problema | chrF score: 0.4671202932853819
# 494 They aren't here. ellos no ellas aquí | chrF score: 0.06480495066334788
# 495 You're sleepy. estás cansada | chrF score: 0.05452673353396863
# 496 Tell us more. sé más | chrF score: 0.026599668999621212
# 497 It's sweltering. es usted | chrF score: 0.024096385542168756
# 498 Open your mouth. ¡abre la boca | chrF score: 0.15042144719936254
# 499 I'm so alone. estoy tan solo | chrF score: 0.38358683446071334
# 500 They live apart. viven en el norte | chrF score: 0.08471195629484049
# 501 We're still investigating. todavía estamos investigando | chrF score: 0.6333961232297944
# 502 Don't be absurd. no seas absurdo | chrF score: 0.41224271568547016
# 503 We both laughed. ambos competimos | chrF score: 0.03144346949384843
# 504 Check everyone. comprueba a todos | chrF score: 0.12345336073659026
# 505 What're you writing? en eres escribir | chrF score: 0.1891337674160672
# 506 Just a minute. solo una momento | chrF score: 0.02072538860103635
# 507 Where's your money? dónde está tu dinero | chrF score: 0.48726963546862245
# 508 I'm really angry. estoy realmente enfadado | chrF score: 0.4204062694104332
# 509 Let's move on. sigamos adelante | chrF score: 0.039919344546823624
# 510 Don't bother me. no me molestes | chrF score: 0.35020851748453863
# 511 Tom was lucky. tom tuvo suerte | chrF score: 0.030303030303030394
# 512 Let's stand up. sigamos adelante | chrF score: 0.04387351778656133
# 513 Tom was terrified. tom estaba aterrorizado | chrF score: 0.5714172820982174
# 514 Tom should've known. tom debía haber sabido | chrF score: 0.2819832589789911
# 515 There's no coffee. hace falta café | chrF score: 0.08174337591496399
# 516 You're something else. eres la bomba | chrF score: 0.026958374303507115
# 517 Come anytime. sal en serio | chrF score: 0.015325670498084368
# 518 We'll see. nosotros estamos a la escucha | chrF score: 0.057263118943546396
# 519 They were shorthanded. estaban faltos de personal | chrF score: 0.3707975821287838
# 520 You're the boss. eres el jefe | chrF score: 0.33830380317050757
# 521 Maybe it'll snow. puede que nieve | chrF score: 0.10978279030910612
# 522 There's nothing here. aquí hay nada | chrF score: 0.19034621412739555
# 523 We're coming. nos estamos viniendo | chrF score: 0.12514617353906596
# 524 You missed. tú te extrañé | chrF score: 0.010526315789473762
# 525 I've gained weight. he comido | chrF score: 0.00896860986547093
# 526 Tom is embarrassed. tomás está avergonzado | chrF score: 0.556412378921195
# 527 Time for dinner. es hora de comer | chrF score: 0.22712231117695691
# 528 Who cheered? quién fue el que vitoreó | chrF score: 0.22588763509002066
# 529 I don't steal. yo no puedo comer | chrF score: 0.03165435034967022
# 530 He is old. Él es viejo | chrF score: 0.057675582122547565
# 531 You're not God. no sos dios | chrF score: 0.09414641784537178
# 532 Is he right? ha acertado | chrF score: 0.018518518518518594
# 533 They know you. te conocen | chrF score: 0.22099323224457196
# 534 I was dreaming. estaba soñando | chrF score: 0.41224271568547016
# 535 Aren't you hot? tú estás sin calor | chrF score: 0.09587609571962488
# 536 Tom is guilty. tom es culpable | chrF score: 0.41224271568547016
# 537 Is Tom here? está aquí tom | chrF score: 0.04269005847953223
# 538 Please sit here. por favor siéntate aquí | chrF score: 0.23194657959978074
# 539 This is nice. esto está bien | chrF score: 0.11392758400471066
# 540 Remember this rule. recuerda esto | chrF score: 0.282843894745704
# 541 It doesn't exist. va a ser existe | chrF score: 0.1697323888777555
# 542 He finally arrived. Él finalmente llegó | chrF score: 0.16945481848823193
# 543 You're new here. estáis aquí | chrF score: 0.06254918641201244
# 544 I'm anorexic. soy imparcial | chrF score: 0.017621145374449417
# 545 Tom, don't leave. tom no vayas | chrF score: 0.09801626737443123
# 546 The rain stopped. dejó de llover | chrF score: 0.008810572687224748
# 547 Tom shed tears. tom parece exhausto | chrF score: 0.030612244897959273
# 548 They stopped kissing. ellos pararon de besarse | chrF score: 0.3226520841100319
# 549 Everyone's reading. todo el mundo leyendo | chrF score: 0.18153234385599087
# 550 Do the dishes. ¡qué los cordones | chrF score: 0.025470026127788703
# 551 Tom is coming. tom va a viniendo | chrF score: 0.2016466956655718
# 552 She fascinated me. ella me fascinaba | chrF score: 0.4622153469253476
# 553 Help yourself. sírvete tú mismo | chrF score: 0.10534267362151764
# 554 Stop gossiping. deja de quejarte | chrF score: 0.03559455856275651
# 555 How's your brother? cómo está tu hermano | chrF score: 0.48726963546862245
# 556 You're my friend. sos mi amiga | chrF score: 0.25118931194162725
# 557 I mean it. hablo en serio | chrF score: 0.22816287168161464
# 558 We're doing nothing. la guerra no lo hizo nada | chrF score: 0.06543081933997795
# 559 Come back here. sal de aquí | chrF score: 0.10231620906199226
# 560 Tom is wet. tom está mojada | chrF score: 0.36596261455834195
# 561 I'm expecting visitors. soy intolerante a los extranjeros | chrF score: 0.05002502051682384
# 562 Are you coming? te va bien | chrF score: 0.010695187165775479
# 563 Please sit down. por favor siéntese | chrF score: 0.22278200043540988
# 564 He's always joking. siempre está bromeando | chrF score: 0.36416857945591447
# 565 Everybody loves her. todos la aman | chrF score: 0.027929704456102555
# 566 Are they brothers? son hermanos | chrF score: 0.20402728607127005
# 567 Who are they? quién son | chrF score: 0.07107462498902742
# 568 Keep your promises. seguí tu tipo | chrF score: 0.007380073800738085
# 569 Call us. sé nuestra | chrF score: 0.010638297872340503
# 570 Tom seemed shy. tomás parecía tímido | chrF score: 0.5230037278728034
# 571 This is good. esto está bien | chrF score: 0.11473234348014752
# 572 He's my husband. Él es mi marido | chrF score: 0.4321233041882162
# 573 Tom was innocent. tom fue inocente | chrF score: 0.2253149694571325
# 574 It's Tom's job. es el trabajo de tom | chrF score: 0.016064257028112528
# 575 Tom got excited. tom se emocionado | chrF score: 0.3626311426568335
# 576 What motivates you? qué tal a usted | chrF score: 0.02542372881355941
# 577 She helped him. ella le ayudó | chrF score: 0.3519782827297096
# 578 Did Tom help? ayudaste a tom | chrF score: 0.08216374269005851
# 579 Nightmares are scary. somos profesores | chrF score: 0.012861736334405224
# 580 Tom was singing. tom estaba cantando | chrF score: 0.5043324742524915
# 581 She adores him. ella lo adora | chrF score: 0.3519782827297096
# 582 The river overflowed. el río se desbordó | chrF score: 0.12047217447915304
# 583 That's not true. eso no es cierto | chrF score: 0.15143974605350197
# 584 We volunteered. nos morimos de voluntario | chrF score: 0.23092253002450985
# 585 I like camels. me gusta la luz de las velas | chrF score: 0.11818856749891234
# 586 I'm just asking. soy sólo | chrF score: 0.009009009009009087
# 587 Tom felt relieved. tom se sintió aliviado | chrF score: 0.44573669981195463
# 588 We're back. hemos vuelto | chrF score: 0.3519782827297096
# 589 I'm unemployed. estoy desempleada | chrF score: 0.06480495066334788
# 590 I lost consciousness. me perdido la perdido | chrF score: 0.028126139951446
# 591 We searched everywhere. estábamos en todas partes | chrF score: 0.09557851713100546
# 592 I'm eating now. ahora soy comiendo | chrF score: 0.3348708857922513
# 593 Let's shake hands. sigamos adelante | chrF score: 0.041841004184100514
# 594 Wait a moment. espera un segundo | chrF score: 0.1735807101775001
# 595 You've done it! ya has hecho | chrF score: 0.009259259259259337
# 596 Write that down. anoten eso | chrF score: 0.10944241430734383
# 597 Who sells this? quién vende esto | chrF score: 0.42164674879399655
# 598 We study French. estábamos francés | chrF score: 0.3176373445926768
# 599 Close that door. cierra eso | chrF score: 0.033414078084924546
# 600 Are you famous? eres desmemoriado | chrF score: 0.05981554677206856
# 601 She spoke rapidly. ella habló en silencio | chrF score: 0.21238657876518915
# 602 I was right. tuve suerte | chrF score: 0.017777777777777854
# 603 We'll go together. vamos a juntos | chrF score: 0.2151513745898145
# 604 We're hungry. estamos hambrientos | chrF score: 0.5230037278728034
# 605 I'll stay home. me voy a casa | chrF score: 0.11855208433920453
# 606 The bridge collapsed. el puente se derrumbó | chrF score: 0.21532734883707422
# 607 I wasn't trapped. yo no estaba atrapado | chrF score: 0.48024731563213574
# 608 Stop deluding yourself. deja de ti mismo | chrF score: 0.19159652267930544
# 609 Coffee, please. café por favor | chrF score: 0.2539615817461114
# 610 The money disappeared. dinero dinero | chrF score: 0.145800148765666
# 611 It tasted sweet. fue los dulce | chrF score: 0.10127711956542942
# 612 Take a card. echa una carta | chrF score: 0.22816287168161464
# 613 Who's speaking? quién va a quién | chrF score: 0.043616065883881616
# 614 You are hopeless. ustedes son inútil | chrF score: 0.021739130434782684
# 615 Who wants cookies? quién quiere ha pasado | chrF score: 0.23476403478966068
# 616 We're studying French. estamos estudiando francés | chrF score: 0.6108920525607621
# 617 It's your choice. tú decides | chrF score: 0.055281224639388504
# 618 It's nice. es agradable | chrF score: 1.0000000000000001e-16
# 619 He's in prison. Él está en te agradezco de antemano | chrF score: 0.19664721227053208
# 620 When was that? eso fue eso | chrF score: 0.18418591954345212
# 621 That's fascinating. así es fascinante | chrF score: 0.37752485037815825
# 622 Don't disappoint me. no me decepciones | chrF score: 0.09587609571962488
# 623 About what time? casi lo que se momento | chrF score: 0.0498056343770466
# 624 Monday's not good. la lunes no está ahí | chrF score: 0.1728640052416806
# 625 I am good. soy reventado | chrF score: 0.031413612565445115
# 626 Tom is intolerant. tom es va a la lactosa | chrF score: 0.05341913836668126
# 627 I've had enough. ya estoy suficiente | chrF score: 0.3149201081974046
# 628 He takes vitamins. Él habla en toma | chrF score: 0.06405285518462708
# 629 Keep smiling. continuad sonriendo | chrF score: 0.2569479188968331
# 630 She's unbelievably naive. ella ella ella ella ella | chrF score: 0.033041613041613085
# 631 I'm motivated. estoy motivado | chrF score: 0.41224271568547016
# 632 I'm a student. soy maderero | chrF score: 0.007905138339921024
# 633 She's very beautiful. ella es muy guapa | chrF score: 0.05403509153552448
# 634 I'm so unlucky! estoy tan tan tan tan tan tan | chrF score: 0.08609725091371367
# 635 Look at us. mira allí | chrF score: 0.011235955056179855
# 636 Who's laughing now? quién se está riendo | chrF score: 0.14823338336052788
# 637 Call me. llámame en la llámame | chrF score: 0.09820645925116404
# 638 We were stranded. estábamos recién colgados | chrF score: 0.2232859461506916
# 639 Tom recovered. tom va a tomás | chrF score: 0.008510638297872419
# 640 You can go. puedes irte | chrF score: 0.1069272871780709
# 641 He looks young. Él luce joven | chrF score: 0.15709354431735353
# 642 I'm getting married. voy a casar | chrF score: 0.3040180888847933
# 643 This is broken. esto está descompuesto | chrF score: 0.17143955948745743
# 644 Weren't they satisfied? no estabas satisfecho | chrF score: 0.36912725370981325
# 645 Say it clearly. dilo claramente | chrF score: 0.2940688257338488
# 646 Tom sang softly. tom cantó suavemente | chrF score: 0.2126485807275814
# 647 My head aches. me duele la espalda | chrF score: 0.20727812446641763
# 648 He is overconfident. es soberbio | chrF score: 1.0000000000000001e-16
# 649 It's started already. ya empezó | chrF score: 0.14361273536933922
# 650 Please fix that. por favor arreglá eso | chrF score: 0.2853996024158614
# 651 Don't bother me. no me molestes | chrF score: 0.02698730485702059
# 652 I've been shot. he estado disparó | chrF score: 0.16542185503283902
# 653 Don't ask. yo hagas preguntas | chrF score: 0.2030648567578794
# 654 Many fish died. esa murió murió | chrF score: 0.04910635818028581
# 655 You're very perceptive. eres muy práctico | chrF score: 0.17485604500090876
# 656 Tom is smoking. tomás está fumar | chrF score: 0.23341213544903533
# 657 Drink something. tómate algo | chrF score: 0.06281558110389099
# 658 I am better. soy viejo | chrF score: 0.03952470293933715
# 659 See you Monday. los vemos lunes | chrF score: 0.10071436423440287
# 660 Watch closely. vigila atentamente | chrF score: 0.01793721973094178
# 661 You're very smart. eres muy lista | chrF score: 0.35307752728218633
# 662 I resigned. recomiendo de acuerdo | chrF score: 0.03084031807436069
# 663 This one's different. este es una diferente | chrF score: 0.3275119083814736
# 664 Enjoy your meal. ¡buen provecho | chrF score: 0.20608816273876837
# 665 We're losing it. lo estamos perdiendo | chrF score: 0.4854449662879848
# 666 Humor Tom. ayuda a tom | chrF score: 0.008928571428571504
# 667 Tom is short. tom es corta | chrF score: 0.08301760130591118
# 668 They are Christians. ellos son cristianos | chrF score: 0.31251746967365374
# 669 Tom apologized. tom ustedes repugnante | chrF score: 0.022900763358778702
# 670 Rules are rules. reglas | chrF score: 0.1041259089393111
# ...
# 1647 Money talks. hace falta dinero | chrF score: 0.06568246649746337
# 1648 Tom likes money. a tom le gusta la dinero | chrF score: 0.3205240520307945
# 1649 I can sing. yo puedo correr | chrF score: 0.09592032743116208
# 1650 Do fish sleep? lo dormir | chrF score: 0.007722007722007799
# 1651 I'm on holiday. soy de vacaciones | chrF score: 0.4296143998273007
# 1652 I contributed. yo ayudó | chrF score: 1.0000000000000001e-16
# 1653 What nonsense! qué pasaría | chrF score: 0.04485788113695097
# 1654 It's Tom's office. es la oficina de tom | chrF score: 0.3583358510172472
# 1655 My sunburn hurts. me duele el estómago | chrF score: 0.13124103546868937
# 1656 He doesn't tan. Él no va a entender | chrF score: 0.07668036325570027
# 1657 They helped Tom. estaban ayudó a tom | chrF score: 0.08109352865860307
# 1658 Tom remembered. tomás se acordó | chrF score: 0.10978279030910612
# 1659 I'm making dinner. soy la cena | chrF score: 0.10960816229860124
# 1660 I feel helpless. me siento inútil | chrF score: 0.23384019884784485
# 1661 Tom agrees. tom va a tom | chrF score: 0.007194244604316623
# 1662 Write Tom. escribe a tom | chrF score: 0.20811887638588034
# 1663 Mom's working. seguí trabajando | chrF score: 0.2630324463499515
# 1664 It's my brother's. es mi hermano | chrF score: 0.27592741092409206
# 1665 Isn't everything beautiful? acaso es bello | chrF score: 0.21912872638304384
# 1666 You're so stubborn. eres tan predecible | chrF score: 0.03629550095791497
# 1667 It takes time. toma tiempo | chrF score: 0.19990090864995788
# 1668 We continued chatting. fuimos escéptico | chrF score: 0.03333938129365878
# 1669 I feel useless. yo me siento mal | chrF score: 0.17374685275523896
# 1670 Have a drink. tómate algo | chrF score: 0.009661835748792346
# 1671 Is it safe? es grave | chrF score: 1.0000000000000001e-16
# 1672 They live there. viven allá | chrF score: 0.22205924199913446
# 1673 I need help. yo necesito ayuda | chrF score: 0.39239284700632193
# 1674 Stop showing off! deja de nuevo | chrF score: 0.031945867694660034
# 1675 How beautiful! ¡qué guapa | chrF score: 0.009708737864077749
# 1676 It wasn't hard. yo no fue difícil | chrF score: 0.1876561340760997
# 1677 Tom understood. tom comprendió | chrF score: 0.1050527475224863
# 1678 Beware of imitations. ojo con las imitaciones | chrF score: 0.556412378921195
# 1679 I saw one. vi a uno | chrF score: 0.03882996920971611
# 1680 Tom changed. tom cambió de cambiado | chrF score: 0.26314837547974845
# 1681 Money isn't everything. hace falta todo | chrF score: 0.05070826446544189
# 1682 I'll wait. lo esperé | chrF score: 0.07735566662379043
# 1683 Isn't it black? no es negra | chrF score: 0.2134945808206245
# 1684 We're cousins. somos primos | chrF score: 0.3519782827297096
# 1685 Tom's sick. tom está enfermo | chrF score: 0.4383427177405885
# 1686 We're through. hemos terminado | chrF score: 0.06617403977754058
# 1687 Get ready. salte | chrF score: 1.0000000000000001e-16
# 1688 Tom waited calmly. tom esperó con calma | chrF score: 0.5043324742524915
# 1689 Well done, guys. vamos a necesitar refugio | chrF score: 0.036908592041671955
# 1690 Be brief. sé breve | chrF score: 0.10337690463440205
# 1691 Isn't that mine? es la mía | chrF score: 0.021505376344086096
# 1692 I'd ask Tom. yo pregúntale a tom | chrF score: 0.07604507825542065
# 1693 Go on ahead. adelante | chrF score: 0.19311488939423288
# 1694 I admired Tom. yo creo a tom | chrF score: 0.016460905349794316
# 1695 You're surrounded. estás vieja | chrF score: 0.05502741539043302
# 1696 I'm thinking. estoy meditando | chrF score: 0.11225987256322138
# 1697 Tom loved animals. a tom le gustan los animales | chrF score: 0.30015449264615
# 1698 I'm educated. soy imparcial | chrF score: 0.016326530612244976
# 1699 Tom corrected himself. tom se quedó sin techo | chrF score: 0.051454289536090714
# 1700 It's beyond reason. es bastante mal | chrF score: 0.026896551724137997
# 1701 Keep smiling. continuad sonriendo | chrF score: 0.3049738469517541
# 1702 I need water. yo necesito agua | chrF score: 0.37992687157288085
# 1703 You understand, right? lo has en lo cierto | chrF score: 0.027303754266211698
# 1704 That's her. ella ella ella ella ella ella | chrF score: 0.06741078741078746
# 1705 You look pleased. pareces aburrido | chrF score: 0.12345336073659026
# 1706 These are Tom's. estos son de tom | chrF score: 0.2818412308694861
# 1707 You're always working. siempre estás trabajando | chrF score: 0.5854381920221512
# 1708 He doesn't sleep. Él no va a dormir | chrF score: 0.010416666666666744
# 1709 He can't sing. Él no sabe cantar | chrF score: 0.18002523894462996
# 1710 It's alive. es vivo | chrF score: 0.06741078741078745
# 1711 Be confident. sé confiado | chrF score: 1.0000000000000001e-16
# 1712 He was patient. Él le paciente | chrF score: 0.24511202422398753
# 1713 Nothing's working. papá está trabajando | chrF score: 0.023904382470119605
# 1714 You always sing. usted siempre canta | chrF score: 0.05341913836668126
# 1715 It's very difficult. es muy difícil | chrF score: 0.38358683446071334
# 1716 Write everything down. anota todo | chrF score: 0.07628023328533826
# 1717 I like honey. me gusta la miel | chrF score: 0.41224271568547016
# 1718 You're the expert. tú eres el experto | chrF score: 0.1588317956395982
# 1719 This is ridiculous. es increíble | chrF score: 0.008196721311475488
# 1720 The clock ticked. el telón se puso claro | chrF score: 0.01438848920863317
# 1721 He's not ready. Él no está listo | chrF score: 0.4585228168125985
# 1722 Business is business. han mejorado | chrF score: 1.0000000000000001e-16
# 1723 You're an angel. ¡eres un ángel | chrF score: 0.260392902390805
# 1724 Now I'm sad. ahora pon triste | chrF score: 0.16599940872910116
# 1725 She likes tigers. a ella le gustan los tigres | chrF score: 0.49470798256255266
# 1726 I'll call him. lo llamaré | chrF score: 0.2778550401099317
# 1727 They're insane. están molidos de la cabeza | chrF score: 0.09194243440984147
# 1728 Hi, guys. qué tal os va | chrF score: 0.03596899224806208
# 1729 I'm a teacher. yo soy profesor | chrF score: 0.028571428571428657
# 1730 We're not rich. somos profesores | chrF score: 0.09110295501599851
# 1731 We study music. estábamos guapa | chrF score: 0.05433136262264633
# 1732 It's too soon. hace demasiado tarde | chrF score: 0.2520915925107682
# 1733 Are you brothers? son hermanos | chrF score: 0.19053321210727064
# 1734 I'm going bald. voy a calvo | chrF score: 0.0767743553784744
# 1735 Silence is golden. el silencio es oro | chrF score: 0.010958904109589118
# 1736 Tom is wicked. tom está implicado | chrF score: 0.0885760462008023
# 1737 Louder, please. le por favor | chrF score: 0.19063203207376708
# 1738 You shouldn't go. por preguntarme ahí | chrF score: 0.025255519031452706
# 1739 I'm losing patience. soy perdiendo le gusta perder | chrF score: 0.2883381132893598
# 1740 I love it. lo adoro | chrF score: 1.0000000000000001e-16
# 1741 You're the scapegoat. eres el chivo expiatorio | chrF score: 0.10522374949509587
# 1742 Don't be evil. no seas mal | chrF score: 0.08248416188905473
# 1743 Tom likes her. a tom le gusta ella | chrF score: 0.1972420785040333
# 1744 Come help me. ayúdame | chrF score: 0.01449275362318848
# 1745 Speak softly. habla más fuerte | chrF score: 0.058076873785637737
# 1746 See you around. los vemos alrededor | chrF score: 0.01793721973094178
# 1747 It looks strange. va a extraño | chrF score: 0.19990090864995788
# 1748 Is he sleeping? está durmiendo | chrF score: 0.3958579138425403
# 1749 Everyone loves sports. todos aman a los deportes | chrF score: 0.2803761922028176
# 1750 These are great. estos son genial | chrF score: 0.1710877177496696
# 1751 Is Tom famous? tom es famoso | chrF score: 0.3366691874778663
# 1752 I'm yours. soy suyo | chrF score: 0.045874352988937446
# 1753 We hate violence. comprendemos esto | chrF score: 0.04963317384370023
# 1754 Please say something. por favor decí algo | chrF score: 0.2129002748132752
# 1755 That's amazing! ¡eso es increíble | chrF score: 0.25636677466272584
# 1756 What's happening? qué pasa | chrF score: 0.05759854018401358
# 1757 I'm drunk. estoy borracho | chrF score: 0.05215419093240307
# 1758 I knew Tom. lo sabía | chrF score: 0.009803921568627529
# 1759 I recognize him. lo conozco | chrF score: 0.20090965760846644
# 1760 I hate winter. odio el invierno | chrF score: 0.4383427177405885
# 1761 They're alone. están solo | chrF score: 0.2645482194724756
# 1762 Move on, Tom. prosigue tom | chrF score: 0.008849557522123972
# 1763 Cold water, please. frío hace frío por favor | chrF score: 0.21159910459910458
# 1764 Remain seated, please. quedaos sentados por favor | chrF score: 0.29546595669124487
# 1765 Who won today? quién ganó a día de hoy | chrF score: 0.09515664108768526
# 1766 Whose is this? de quién es esto | chrF score: 0.3958579138425403
# 1767 I'm not here. no voy aquí | chrF score: 0.1456127272671923
# 1768 We're all invited. estamos todos invitadas | chrF score: 0.5039239406963619
# 1769 Get in here! aquí | chrF score: 0.06184287840252618
# 1770 French is difficult. es francés | chrF score: 0.15968116808019361
# 1771 Let's eat sushi. comamos | chrF score: 0.14430620872102284
# 1772 He finished breakfast. Él terminó el desayuno | chrF score: 0.3929152566846395
# 1773 She said goodbye. ella dijo chao | chrF score: 0.18166665913231428
# 1774 I'm freaking out. soy fuera | chrF score: 0.014440433212996467
# 1775 Don't sass me. no me sermonees | chrF score: 0.017391304347826163
# 1776 I hate sand. odio la arena | chrF score: 0.369356132095177
# 1777 He isn't married. Él no va a casada | chrF score: 0.1350913822872542
# 1778 Tom wants children. tom quiere a niños | chrF score: 0.22433934777486786
# 1779 They know him. lo hicieron | chrF score: 0.016460905349794316
# 1780 Be objective. sean objetivos | chrF score: 0.2590368077055384
# 1781 Tom answered. tom respondió | chrF score: 0.38358683446071334
# 1782 I'll be going. voy a ir | chrF score: 0.05379258422736688
# 1783 He is bankrupt. Él es va | chrF score: 0.04977220090073386
# 1784 Are you Tom? tú eres tom | chrF score: 0.018604651162790774
# 1785 Stand up, please. por favor date mi favor | chrF score: 0.16757536908105047
# 1786 We're twins. somos gemelos | chrF score: 0.38358683446071334
# 1787 Stop right here. párate aquí mismo | chrF score: 0.30873531165830853
# 1788 Adjust the brakes. ¡qué los estados unidos | chrF score: 0.05404095480431366
# 1789 Count me in. cuenta conmigo | chrF score: 0.41224271568547016
# 1790 I'm just joking. es sólo una broma | chrF score: 0.06828639364404751
# 1791 Tom apologized again. tom volvió a preguntar | chrF score: 0.15920384963013762
# 1792 Tom's Canadian. tom es canadiense | chrF score: 0.4622153469253476
# 1793 Who phoned? quién va a quién | chrF score: 0.038566346911288074
# 1794 We're ambidextrous. somos ambidiestros | chrF score: 0.2928758195905957
# 1795 Never say never. nunca hay que decir | chrF score: 0.08077995283871833
# 1796 I'm a farmer. soy maderero | chrF score: 0.03442080378250597
# 1797 It is second-hand. es maravilloso | chrF score: 0.02352941176470596
# 1798 Tom writes slowly. tom escribe lentamente | chrF score: 0.2347315818124418
# 1799 Tom is furious. tom está sólo | chrF score: 0.13045286538479972
# 1800 They're insane. están molidos de la cabeza | chrF score: 0.005376344086021586
# 1801 Tom came early. tom subió temprano | chrF score: 0.21503006245091374
# 1802 I have time. gané | chrF score: 1.0000000000000001e-16
# 1803 I like clocks. me gusta la luz de las velas | chrF score: 0.11514088368207971
# 1804 You look awful. pareces aburrido | chrF score: 0.04220642780142887
# 1805 I require advice. yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo yo | chrF score: 1.0000000000000001e-16
# 1806 Are you sure? está segura | chrF score: 0.1154918473500112
# 1807 Everybody's dead. todos muerto | chrF score: 0.16214563089176892
# 1808 Stay close. mantente cerca | chrF score: 0.024390243902439105
# 1809 That's my book. esa es mi libro | chrF score: 0.28651389500570756
# 1810 Some fish fly. algo se me hizo tarde | chrF score: 0.03521840478362224
# 1811 He was cheating. Él estaba trampas | chrF score: 0.1727012587095473
# 1812 Does everybody understand? lo hace | chrF score: 1.0000000000000001e-16
# 1813 I ate it. lo conozco | chrF score: 0.010638297872340503
# 1814 Tom's my cousin. tom es mi héroe | chrF score: 0.14090448582319895
# 1815 I'm not short. no soy pequeño | chrF score: 0.06216374269005853
# 1816 What for? qué sirve | chrF score: 0.032689809359799454
# 1817 You're cute. estás tan gordo | chrF score: 0.029047619047619117
# 1818 He got angry. Él se enojó | chrF score: 0.15639354586548668
# 1819 Throw the dice. tira el dado | chrF score: 0.19990090864995788
# 1820 They despise you. ellos te menosprecio | chrF score: 0.23441459829697683
# 1821 Tom likes chocolate. a tom le gusta el chocolate | chrF score: 0.5527955299766514
# 1822 They're small. están pequeño | chrF score: 0.25785291026810325
# 1823 It's dark. está oscuro | chrF score: 0.31693316559071566
# 1824 It's Tom's car. es el coche de tom | chrF score: 0.050788736547250544
# 1825 Spring has come. la primavera llegó | chrF score: 0.3677910500023044
# 1826 I'm better. mejor que mejor | chrF score: 0.1002589807852966
# 1827 How's this possible? cómo va en posible | chrF score: 0.17749442229817264
# 1828 We're moving. nos estoy moviendo | chrF score: 0.052339817045699455
# 1829 I gave up. yo adoro el teléfono | chrF score: 1.0000000000000001e-16
# 1830 Tom was sleeping. tom estaba durmiendo | chrF score: 0.5230037278728034
# 1831 He loved her. Él la amaba | chrF score: 0.060287065029582185
# 1832 It's my turn. es mi turno | chrF score: 0.2778550401099317
# 1833 Is something wrong? está algo mal | chrF score: 0.06827894327894332
# 1834 I'm not persuaded. no me convence | chrF score: 0.1560663854762499
# 1835 Tom shrugged. tom ronca | chrF score: 0.01973684210526324
# 1836 Let's try! hagámoslo | chrF score: 0.08987215301668358
# 1837 Just ask Tom. solo levántate a tom | chrF score: 0.06344380257423742
# 1838 She's stark naked. ella está totalmente en canicas | chrF score: 0.17154884629235018
# 1839 There's no water. no hay agua | chrF score: 0.2778550401099317
# 1840 Tom ignored Mary. tom ignoraste a mary | chrF score: 0.20310295501599854
# 1841 Stop babbling. deja de chismorrear | chrF score: 0.031198151680079455
# 1842 Get some rest. descansa un poco de ello | chrF score: 0.283379752049737
# 1843 You're very patient. eres muy paciente | chrF score: 0.39239284700632193
# 1844 I'm your sister. yo soy tu hermana | chrF score: 0.37992687157288085
# 1845 I don't drink. yo no bebo | chrF score: 0.032689809359799454
# 1846 It wasn't that. eso no era | chrF score: 0.09935028881781442
# 1847 Tom walked. tom siguió caminando | chrF score: 0.1217336847901476
# 1848 Who escaped? quién escapó | chrF score: 0.3366691874778663
# 1849 Prices are high. los precios son altos | chrF score: 0.31162500752832173
# 1850 I'm not rich. yo no soy rico | chrF score: 0.2747828712368555
# 1851 That smells delicious. eso huele delicioso | chrF score: 0.16443120579470158
# 1852 I went hiking. yo fui de excursión | chrF score: 0.08712591756070019
# 1853 Tom is hysterical. tom está implicado | chrF score: 0.0656306686980698
# 1854 You may go. podéis ir | chrF score: 0.06232170287469833
# 1855 Play it again. tócalo otra vez | chrF score: 0.08828200779557197
# 1856 Continue without me. ¡qué me enseñó | chrF score: 0.008474576271186517
# 1857 Tom got nervous. tom se nervioso | chrF score: 0.2475262961877088
# 1858 Everyone was drinking. todos estaba bebiendo | chrF score: 0.415699985965163
# 1859 You must rest. tienes que correr | chrF score: 0.059301113241179884
# 1860 They already know. ya son sensatos | chrF score: 0.032786885245901724
# 1861 Breathe normally. inspira profundamente | chrF score: 0.10202429075954433
# 1862 Is Tom lonely? tom está solo | chrF score: 0.06993900540049051
# 1863 Please calm down. por favor tranquilícese | chrF score: 0.16341932665272046
# 1864 Thanks for dinner. gracias por la cena | chrF score: 0.4841349520272651
# 1865 We're very pleased. estamos muy confundida | chrF score: 0.3286946170637575
# 1866 They hated Tom. ellos odiaban a tom | chrF score: 0.2030648567578794
# 1867 Tom liked that. a tom le gustó | chrF score: 0.2649189171294183
#
#
# Average chrF score: 0.1613702012177693
